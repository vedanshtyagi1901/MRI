# %%
import os
import cv2
import glob
import PIL
import shutil
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from skimage import data
from skimage.util import montage 
import skimage.transform as skTrans
from skimage.transform import rotate
from skimage.transform import resize
from PIL import Image, ImageOps  


# neural imaging
import nilearn as nl
import nibabel as nib
import nilearn.plotting as nlplt



# ml libs
import keras
import keras.backend as K
from keras.callbacks import CSVLogger
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
from tensorflow.keras.models import *
from tensorflow.keras.layers import *
from tensorflow.keras.optimizers import *
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau, EarlyStopping, TensorBoard
 


# Make numpy printouts easier to read.
np.set_printoptions(precision=3, suppress=True)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
print(tf.test.is_built_with_cuda())
print(tf.test.is_built_with_gpu_support())
print(tf.test.gpu_device_name())
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU'), PhysicalDevice(name='/physical_device:GPU:1', device_type='GPU')]
# True
# True
# /device:GPU:0

# %%
import nibabel as nib
import matplotlib.pyplot as plt

TRAIN_DATASET_PATH = '/kaggle/input/brain-tumor-segmentation-in-mri-brats-2015/MICCAI_BraTS2020_TrainingData/'


modalities = ['flair', 't1', 't1ce', 't2']
image_data = {}


for modality in modalities:
    image_data[modality] = nib.load(f'{TRAIN_DATASET_PATH}BraTS20_Training_001/BraTS20_Training_001_{modality}.nii').get_fdata()


test_mask = nib.load(f'{TRAIN_DATASET_PATH}BraTS20_Training_001/BraTS20_Training_001_seg.nii').get_fdata()


#print("Shape of Images ",image_data['flair'].shape)


fig, axes = plt.subplots(1, 5, figsize=(20, 10))
slice_w = 70


titles = ['Image flair', 'Image t1', 'Image t1ce', 'Image t2', 'Mask']


for ax, (modality, title) in zip(axes, zip(modalities, titles)):
    ax.imshow(image_data[modality][:, :, image_data[modality].shape[0] // 2 - slice_w], cmap='gray')
    ax.set_title(title)


axes[4].imshow(test_mask[:, :, test_mask.shape[0] // 2 - slice_w], cmap='gray')

axes[4].set_title('Mask')

plt.show()

# %%
unique_labels = np.unique(test_mask)
print("Unique labels in the mask:", unique_labels)
# Out:
# Unique labels in the mask: [0. 1. 2. 4.]

# %%
print(np.unique(test_mask))  #0, 1, 2, 4 (Need to reencode to 0, 1, 2, 3)
test_mask[test_mask==4] = 3  #Reassign mask values 4 to 3
print(np.unique(test_mask))
# Out:
# [0. 1. 2. 4.]
# [0. 1. 2. 3.]

# %%
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

slice_index = 70

# Extract the mask slice
mask_slice = test_mask[:, :, slice_index]


class_colors = ['black', 'blue', 'pink', 'cyan'] 
cmap = ListedColormap(class_colors)


class_labels = ['Non-tumor', 'Necrotic/Core', 'Edema', 'Enhancing Tumor']


plt.figure(figsize=(10, 10))
plt.imshow(mask_slice, cmap=cmap)


colorbar = plt.colorbar(ticks=[0, 1, 2, 3])  # Set ticks to match class values
colorbar.set_ticklabels(class_labels)  # Set tick labels to class names

plt.title(f'Mask with 4 Classes (Slice {slice_index})')
plt.axis('off')
plt.show()

# %%
 

# Extract the flair image and mask slices
flair_slice = image_data['flair'][:, :, slice_index]
mask_slice = test_mask[:, :, slice_index]

 
class_colors = ['black', 'blue', 'pink', 'cyan'] 
cmap = ListedColormap(class_colors)

 
plt.figure(figsize=(10, 10))

# Display the flair image
plt.imshow(flair_slice, cmap='gray')

# Overlay the mask with transparency
plt.imshow(mask_slice, cmap=cmap, alpha=0.4)

# Add a colorbar with class labels
colorbar = plt.colorbar(ticks=[0, 1, 2, 3])  # Set ticks to match class values
colorbar.set_ticklabels(['Non-tumor', 'Necrotic/Core', 'Edema', 'Enhancing Tumor'])  # Set tick labels to class names

plt.title(f'Flair Image with Mask Overlay (Slice {slice_index})')
plt.axis('off')
plt.show()

# %%
from nilearn import plotting, image
import nibabel as nib

flair_niimg = nib.load(f"{TRAIN_DATASET_PATH}BraTS20_Training_001/BraTS20_Training_001_flair.nii")
mask_niimg = nib.load(f"{TRAIN_DATASET_PATH}BraTS20_Training_001/BraTS20_Training_001_seg.nii")

 
display = plotting.plot_anat(
    flair_niimg,
    title="Overlay: Flair with Mask",
    display_mode="ortho",  # Displays all three planes (axial, sagittal, coronal)
    dim=-1  
)


display.add_overlay(mask_niimg, cmap="tab10", alpha=0.5)


plotting.show()

# %%
# Stack all modalities along the third axis to create a multi-channel image
combined_modalities = np.stack([image_data['flair'], image_data['t1ce'], image_data['t2']], axis=-1)

# Print shape to verify
print("Shape of combined modalities:", combined_modalities.shape)
# Out:
# Shape of combined modalities: (240, 240, 155, 3)

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assume combined_modalities has shape (240, 240, 155, 3)
modalities = ['Flair', 'T1ce', 'T2']
slice_index = 70

# Plot each modality as a separate panel
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

for i, (modality, ax) in enumerate(zip(modalities, axes)):
    # Access the specific slice for each modality
    modality_slice = combined_modalities[:, :, slice_index, i]
    ax.imshow(modality_slice, cmap='gray')
    ax.set_title(modality)
    ax.axis('off')

plt.tight_layout()
plt.show()

# Average all modalities across the 4th axis (channels)
combined_grayscale = np.mean(combined_modalities, axis=-1)

# Display the combined grayscale slice
plt.figure(figsize=(8, 8))
plt.imshow(combined_grayscale[:, :, slice_index], cmap='gray')
plt.title("Combined Modalities (Averaged)")
plt.axis('off')
plt.show()

# %%
for modality in ['flair', 't1ce', 't2']:
    print(f"Shape of {modality} image slice: {image_data[modality].shape}")

print(f"Shape of Combined Modalitiess {combined_modalities.shape}")
print(f"Shape of mask_slice {test_mask.shape}")
# Out:
# Shape of flair image slice: (240, 240, 155)
# Shape of t1ce image slice: (240, 240, 155)
# Shape of t2 image slice: (240, 240, 155)
# Shape of Combined Modalitiess (240, 240, 155, 3)
# Shape of mask_slice (240, 240, 155)

# %%
def crop_borders(image, mask, threshold=0):
 
    # Use the middle slice as a reference for cropping
    slice_index = image.shape[2] // 2
    ref_image = np.mean(image[:, :, slice_index, :], axis=-1)  # Averaging across channels for reference

    # Find non-zero pixels (above the threshold) in the reference slice
    rows = np.any(ref_image > threshold, axis=1)
    cols = np.any(ref_image > threshold, axis=0)
    
    # Find bounding box
    row_start, row_end = np.where(rows)[0][[0, -1]]
    col_start, col_end = np.where(cols)[0][[0, -1]]
    
    # Crop the image and mask using the computed boundaries
    cropped_image = image[row_start:row_end + 1, col_start:col_end + 1, :, :]
    cropped_mask = mask[row_start:row_end + 1, col_start:col_end + 1, :]
    
    return cropped_image, cropped_mask

# %%
cropped_combined,cropped_mask=crop_borders(combined_modalities,test_mask)

# %%
from skimage.transform import resize
import numpy as np

# Define the target size
target_size = (128, 128)

# Resize each modality
resized_slices = np.zeros((target_size[0], target_size[1], cropped_combined.shape[2], cropped_combined.shape[3]))

for i in range(cropped_combined.shape[3]):  # Iterate over modalities
    for j in range(cropped_combined.shape[2]):  # Iterate over slices (depth dimension)
        resized_slices[:, :, j, i] = resize(
            cropped_combined[:, :, j, i],
            target_size,
            anti_aliasing=True
        )

# Resize the mask (use nearest neighbor interpolation for class labels)
resized_mask = np.zeros((target_size[0], target_size[1], cropped_mask.shape[2]))

for j in range(cropped_mask.shape[2]):  # Iterate over slices (depth dimension)
    resized_mask[:, :, j] = resize(
        cropped_mask[:, :, j],
        target_size,
        order=0,  # Nearest neighbor interpolation
        preserve_range=True,
        anti_aliasing=False
    )

# Check the resized shapes
print("Shapes after resizing:")
print(f"Resized combined modalities shape: {resized_slices.shape}")
print(f"Resized mask shape: {resized_mask.shape}")
# Out:
# Shapes after resizing:
# Resized combined modalities shape: (128, 128, 155, 3)
# Resized mask shape: (128, 128, 155)

# %%
target_size = (128, 128)
original_depth = 155  # Assuming the original depth is 155 slices
reduced_depth = original_depth - 120 




def preprocess_data(image_data, mask_data, target_size=(128, 128), original_depth=155, reduced_depth=35):
    num_modalities = image_data.shape[3]
    num_classes = 4

    # Remove 20 slices from the beginning and 20 from the end
    image_data = image_data[..., 60:original_depth-60, :]
    mask_data = mask_data[..., 60:original_depth-60]

    # Initialize resized modalities array
    combined_modalities = np.zeros((*target_size, reduced_depth, num_modalities), dtype=np.float32)

    # Resize each slice of each modality
    for i in range(num_modalities):
        for z in range(reduced_depth):  # Process each slice
            combined_modalities[..., z, i] = resize(
                image_data[..., z, i], target_size, mode='reflect', anti_aliasing=True
            )

    # Resize and one-hot encode the mask
    resized_mask = np.zeros((*target_size, reduced_depth), dtype=np.uint8)
    for z in range(reduced_depth):  # Resize each slice of the mask
        resized_mask[..., z] = resize(
            mask_data[..., z], target_size, order=0, preserve_range=True, anti_aliasing=False
        ).astype(np.uint8)

    one_hot_mask = np.zeros((*resized_mask.shape, num_classes), dtype=np.uint8)
    for i, label in enumerate(range(num_classes)):  # Labels in the mask: 0, 1, 2, 3
        one_hot_mask[resized_mask == label, i] = 1

    return combined_modalities, one_hot_mask

# %%
import matplotlib.pyplot as plt
import numpy as np

# Choose a slice index to visualize
slice_index = 70  # or any index within the range of your mask and combined image

# Plot cropped and resized slices along with the mask
fig, axes = plt.subplots(3, 3, figsize=(20, 15))

modalities = ['flair', 't1ce', 't2']
modality_indices = [0, 1, 2]  # Indices for flair, t1ce, and t2 modalities

# Plot cropped images for each modality
for i, modality_idx in enumerate(modality_indices):
    axes[0, i].imshow(cropped_combined[:, :, slice_index, modality_idx], cmap='gray')
    axes[0, i].set_title(f"Cropped {modalities[i]}")
    axes[0, i].axis('off')

# Plot resized images for each modality
for i, modality_idx in enumerate(modality_indices):
    axes[1, i].imshow(resized_slices[:, :, slice_index, modality_idx], cmap='gray')
    axes[1, i].set_title(f"Resized {modalities[i]}")
    axes[1, i].axis('off')

# Plot cropped mask (select a slice if the mask is 3D, otherwise show the whole image)
axes[2, 0].imshow(cropped_mask[:, :, slice_index], cmap='gray')  # Select a slice if mask is 3D
axes[2, 0].set_title("Cropped Mask")
axes[2, 0].axis('off')

# Plot resized mask (select a slice if the mask is 3D, otherwise show the whole image)
axes[2, 1].imshow(resized_mask[:, :, slice_index], cmap='gray')  # Select a slice if mask is 3D
axes[2, 1].set_title("Resized Mask")
axes[2, 1].axis('off')

# Plot the combined averaged image (slice_index) from resized modalities
# We average the modalities (flair, t1ce, t2) for the selected slice
combined_avg = np.mean(resized_slices[:, :, slice_index, :3], axis=-1)  # Average across flair, t1ce, and t2
axes[2, 2].imshow(combined_avg, cmap='gray')  # Display the combined averaged image
axes[2, 2].set_title("Combined Modalities (Average)")
axes[2, 2].axis('off')

# Hide extra axes in the last row
for ax in axes[2, 3:]:
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
# Assuming `resized_slices` and `resized_mask` are ready from earlier preprocessing:
combined_modalities, one_hot_mask = preprocess_data(resized_slices, resized_mask)

print("Combined modalities shape:", combined_modalities.shape)  # Should be (H, W, D, modalities)
print("One-hot encoded mask shape:", one_hot_mask.shape)        # Should be (H, W, D, 4)
# Out:
# Combined modalities shape: (128, 128, 35, 3)
# One-hot encoded mask shape: (128, 128, 35, 4)

# %%
from sklearn.model_selection import train_test_split

# Get all patient directories, excluding BraTS20_Training_355
patient_ids = [
    d for d in os.listdir(TRAIN_DATASET_PATH) 
    if os.path.isdir(os.path.join(TRAIN_DATASET_PATH, d)) and d != "BraTS20_Training_355"
]

# Print the patient_ids list

print(f"Found {len(patient_ids)} patient IDs.")

# Split patient IDs into train, validation, and test
train_ids, val_ids = train_test_split(patient_ids, test_size=0.2, random_state=42)
#train_ids, val_ids = train_test_split(train_ids, test_size=0.2, random_state=42)

# Initialize data generators




print(f"Train set size: {len(train_ids)}")
#print(f"Test set size: {len(test_ids)}")
print(f"Validation set size: {len(val_ids)}")
# show number of data for each dir 
def showDataLayout():
    plt.bar(["Train","Valid"],
    [len(train_ids), len(val_ids)], align='center',color=[ 'green','red'])
    plt.legend()

    plt.ylabel('Number of images')
    plt.title('Data distribution')

    plt.show()
    
showDataLayout()
# Out:
# Found 368 patient IDs.
# Train set size: 294
# Validation set size: 74

# %%
import os
import nibabel as nib
import numpy as np
from skimage.transform import resize
from tqdm import tqdm

# Directories to save processed data
train_save_dir = "/kaggle/working/train_data"
val_save_dir = "/kaggle/working/val_data"
dataset_path=TRAIN_DATASET_PATH
# Make directories
os.makedirs(os.path.join(train_save_dir, "images"), exist_ok=True)
os.makedirs(os.path.join(train_save_dir, "masks"), exist_ok=True)
os.makedirs(os.path.join(val_save_dir, "images"), exist_ok=True)
os.makedirs(os.path.join(val_save_dir, "masks"), exist_ok=True)

# List of patient IDs (excluding 355 and ignoring unwanted files)
patient_ids = [p for p in os.listdir(dataset_path) if p.startswith("BraTS20") and p != "BraTS20_Training_355"]

# Split into train and val
split_idx = int(0.8 * len(patient_ids))
train_patients = patient_ids[:split_idx]
val_patients = patient_ids[split_idx:]

def load_and_preprocess_patient(patient_id, save_dir, target_size=(128, 128), num_modalities=3, num_classes=4):
    """Load, preprocess, and save slices for a single patient."""
    patient_path = os.path.join(dataset_path, patient_id)
    modalities = ['flair', 't1ce', 't2'][:num_modalities]
    
    # Load and normalize modalities
    image_data = []
    for modality in modalities:
        modality_path = os.path.join(patient_path, f"{patient_id}_{modality}.nii")
        img = nib.load(modality_path).get_fdata()
        img = (img - np.min(img)) / (np.max(img) - np.min(img))  # Normalize
        image_data.append(img)
    
    # Stack modalities together: (H, W, S, C)
    combined_data = np.stack(image_data, axis=-1)
    
    # Load mask and remap labels
    mask_path = os.path.join(patient_path, f"{patient_id}_seg.nii")
    mask_data = nib.load(mask_path).get_fdata()
    mask_data[mask_data == 4] = 3  # Remap label 4 to 3
    
    # Save slices excluding first and last 60 slices
    num_slices = mask_data.shape[2]
    valid_slices = range(60, num_slices - 60)
    
    for z_index in tqdm(valid_slices, desc=f"Processing {patient_id}"):
        # Extract slices
        slice_img = combined_data[:, :, z_index, :]
        slice_mask = mask_data[:, :, z_index]
        
        # Resize images and masks
        resized_img = resize(slice_img, (target_size[0], target_size[1]), preserve_range=True, mode='reflect', anti_aliasing=True)
        resized_mask = resize(slice_mask, (target_size[0], target_size[1]), preserve_range=True, mode='reflect', anti_aliasing=True)
        
        # One-hot encode mask
        resized_mask = np.eye(num_classes)[resized_mask.astype(np.int32)]
        
        # Save to disk
        np.save(os.path.join(save_dir, "images", f"{patient_id}_slice{z_index}.npy"), resized_img)
        np.save(os.path.join(save_dir, "masks", f"{patient_id}_slice{z_index}.npy"), resized_mask)

# Process and save train data
for patient in train_patients:
    load_and_preprocess_patient(patient, train_save_dir)

# Process and save validation data
for patient in val_patients:
    load_and_preprocess_patient(patient, val_save_dir)

print("Preprocessing and saving completed successfully!")
# Out:
# Processing BraTS20_Training_083: 100%|██████████| 35/35 [00:00<00:00, 124.33it/s]
# Processing BraTS20_Training_337: 100%|██████████| 35/35 [00:00<00:00, 123.73it/s]
# Processing BraTS20_Training_161: 100%|██████████| 35/35 [00:00<00:00, 132.91it/s]
# Processing BraTS20_Training_198: 100%|██████████| 35/35 [00:00<00:00, 128.37it/s]
# Processing BraTS20_Training_284: 100%|██████████| 35/35 [00:00<00:00, 133.15it/s]
# Processing BraTS20_Training_169: 100%|██████████| 35/35 [00:00<00:00, 120.50it/s]
# Processing BraTS20_Training_157: 100%|██████████| 35/35 [00:00<00:00, 124.47it/s]
# Processing BraTS20_Training_073: 100%|██████████| 35/35 [00:00<00:00, 129.55it/s]
# Processing BraTS20_Training_253: 100%|██████████| 35/35 [00:00<00:00, 130.32it/s]
# Processing BraTS20_Training_026: 100%|██████████| 35/35 [00:00<00:00, 126.34it/s]
# Processing BraTS20_Training_100: 100%|██████████| 35/35 [00:00<00:00, 127.98it/s]
# Processing BraTS20_Training_107: 100%|██████████| 35/35 [00:00<00:00, 130.88it/s]
# Processing BraTS20_Training_245: 100%|██████████| 35/35 [00:00<00:00, 132.81it/s]
# Processing BraTS20_Training_358: 100%|██████████| 35/35 [00:00<00:00, 127.30it/s]
# Processing BraTS20_Training_310: 100%|██████████| 35/35 [00:00<00:00, 132.95it/s]
# Processing BraTS20_Training_205: 100%|██████████| 35/35 [00:00<00:00, 123.13it/s]
# Processing BraTS20_Training_225: 100%|██████████| 35/35 [00:00<00:00, 131.40it/s]
# Processing BraTS20_Training_320: 100%|██████████| 35/35 [00:00<00:00, 131.42it/s]
# Processing BraTS20_Training_162: 100%|██████████| 35/35 [00:00<00:00, 125.91it/s]
# Processing BraTS20_Training_108: 100%|██████████| 35/35 [00:00<00:00, 130.09it/s]
# Processing BraTS20_Training_048: 100%|██████████| 35/35 [00:00<00:00, 122.01it/s]
# Processing BraTS20_Training_218: 100%|██████████| 35/35 [00:00<00:00, 125.81it/s]
# Processing BraTS20_Training_289: 100%|██████████| 35/35 [00:00<00:00, 128.79it/s]
# Processing BraTS20_Training_045: 100%|██████████| 35/35 [00:00<00:00, 122.30it/s]
# Processing BraTS20_Training_334: 100%|██████████| 35/35 [00:00<00:00, 127.98it/s]
# Processing BraTS20_Training_054: 100%|██████████| 35/35 [00:00<00:00, 124.32it/s]
# Processing BraTS20_Training_354: 100%|██████████| 35/35 [00:00<00:00, 129.03it/s]
# Processing BraTS20_Training_243: 100%|██████████| 35/35 [00:00<00:00, 120.92it/s]
# Processing BraTS20_Training_142: 100%|██████████| 35/35 [00:00<00:00, 130.02it/s]
# Processing BraTS20_Training_179: 100%|██████████| 35/35 [00:00<00:00, 114.93it/s]
# Processing BraTS20_Training_307: 100%|██████████| 35/35 [00:00<00:00, 117.89it/s]
# Processing BraTS20_Training_070: 100%|██████████| 35/35 [00:00<00:00, 123.54it/s]
# Processing BraTS20_Training_238: 100%|██████████| 35/35 [00:00<00:00, 129.50it/s]
# Processing BraTS20_Training_146: 100%|██████████| 35/35 [00:00<00:00, 131.66it/s]
# Processing BraTS20_Training_195: 100%|██████████| 35/35 [00:00<00:00, 130.48it/s]
# Processing BraTS20_Training_060: 100%|██████████| 35/35 [00:00<00:00, 129.01it/s]
# Processing BraTS20_Training_322: 100%|██████████| 35/35 [00:00<00:00, 128.83it/s]
# Processing BraTS20_Training_303: 100%|██████████| 35/35 [00:00<00:00, 131.93it/s]
# Processing BraTS20_Training_215: 100%|██████████| 35/35 [00:00<00:00, 124.63it/s]
# Processing BraTS20_Training_031: 100%|██████████| 35/35 [00:00<00:00, 129.73it/s]
# Processing BraTS20_Training_145: 100%|██████████| 35/35 [00:00<00:00, 127.60it/s]
# Processing BraTS20_Training_166: 100%|██████████| 35/35 [00:00<00:00, 131.16it/s]
# Processing BraTS20_Training_339: 100%|██████████| 35/35 [00:00<00:00, 125.49it/s]
# Processing BraTS20_Training_342: 100%|██████████| 35/35 [00:00<00:00, 118.83it/s]
# Processing BraTS20_Training_363: 100%|██████████| 35/35 [00:00<00:00, 130.41it/s]
# Processing BraTS20_Training_350: 100%|██████████| 35/35 [00:00<00:00, 124.76it/s]
# Processing BraTS20_Training_274: 100%|██████████| 35/35 [00:00<00:00, 113.33it/s]
# Processing BraTS20_Training_257: 100%|██████████| 35/35 [00:00<00:00, 131.88it/s]
# Processing BraTS20_Training_302: 100%|██████████| 35/35 [00:00<00:00, 124.37it/s]
# Processing BraTS20_Training_258: 100%|██████████| 35/35 [00:00<00:00, 125.22it/s]
# Processing BraTS20_Training_279: 100%|██████████| 35/35 [00:00<00:00, 119.16it/s]
# Processing BraTS20_Training_114: 100%|██████████| 35/35 [00:00<00:00, 127.87it/s]
# Processing BraTS20_Training_235: 100%|██████████| 35/35 [00:00<00:00, 125.34it/s]
# Processing BraTS20_Training_331: 100%|██████████| 35/35 [00:00<00:00, 122.41it/s]
# Processing BraTS20_Training_219: 100%|██████████| 35/35 [00:00<00:00, 128.80it/s]
# Processing BraTS20_Training_316: 100%|██████████| 35/35 [00:00<00:00, 131.73it/s]
# Processing BraTS20_Training_266: 100%|██████████| 35/35 [00:00<00:00, 130.05it/s]
# Processing BraTS20_Training_004: 100%|██████████| 35/35 [00:00<00:00, 129.65it/s]
# Processing BraTS20_Training_328: 100%|██████████| 35/35 [00:00<00:00, 118.31it/s]
# Processing BraTS20_Training_368: 100%|██████████| 35/35 [00:00<00:00, 125.20it/s]
# Processing BraTS20_Training_119: 100%|██████████| 35/35 [00:00<00:00, 115.42it/s]
# Processing BraTS20_Training_364: 100%|██████████| 35/35 [00:00<00:00, 121.13it/s]
# Processing BraTS20_Training_281: 100%|██████████| 35/35 [00:00<00:00, 124.04it/s]
# Processing BraTS20_Training_227: 100%|██████████| 35/35 [00:00<00:00, 130.37it/s]
# Processing BraTS20_Training_065: 100%|██████████| 35/35 [00:00<00:00, 119.57it/s]
# Processing BraTS20_Training_127: 100%|██████████| 35/35 [00:00<00:00, 131.43it/s]
# Processing BraTS20_Training_268: 100%|██████████| 35/35 [00:00<00:00, 125.48it/s]
# Processing BraTS20_Training_273: 100%|██████████| 35/35 [00:00<00:00, 129.10it/s]
# Processing BraTS20_Training_180: 100%|██████████| 35/35 [00:00<00:00, 127.43it/s]
# Processing BraTS20_Training_292: 100%|██████████| 35/35 [00:00<00:00, 133.61it/s]
# Processing BraTS20_Training_173: 100%|██████████| 35/35 [00:00<00:00, 121.75it/s]
# Processing BraTS20_Training_207: 100%|██████████| 35/35 [00:00<00:00, 122.96it/s]
# Processing BraTS20_Training_222: 100%|██████████| 35/35 [00:00<00:00, 132.17it/s]
# Processing BraTS20_Training_034: 100%|██████████| 35/35 [00:00<00:00, 114.16it/s]
# Processing BraTS20_Training_027: 100%|██████████| 35/35 [00:00<00:00, 132.66it/s]
# Processing BraTS20_Training_010: 100%|██████████| 35/35 [00:00<00:00, 128.45it/s]
# Processing BraTS20_Training_110: 100%|██████████| 35/35 [00:00<00:00, 102.68it/s]
# Processing BraTS20_Training_244: 100%|██████████| 35/35 [00:00<00:00, 117.70it/s]
# Processing BraTS20_Training_076: 100%|██████████| 35/35 [00:00<00:00, 132.08it/s]
# Processing BraTS20_Training_141: 100%|██████████| 35/35 [00:00<00:00, 129.37it/s]
# Processing BraTS20_Training_097: 100%|██████████| 35/35 [00:00<00:00, 126.50it/s]
# Processing BraTS20_Training_158: 100%|██████████| 35/35 [00:00<00:00, 119.31it/s]
# Processing BraTS20_Training_095: 100%|██████████| 35/35 [00:00<00:00, 130.08it/s]
# Processing BraTS20_Training_361: 100%|██████████| 35/35 [00:00<00:00, 128.24it/s]
# Processing BraTS20_Training_318: 100%|██████████| 35/35 [00:00<00:00, 126.12it/s]
# Processing BraTS20_Training_324: 100%|██████████| 35/35 [00:00<00:00, 123.66it/s]
# Processing BraTS20_Training_052: 100%|██████████| 35/35 [00:00<00:00, 130.89it/s]
# Processing BraTS20_Training_263: 100%|██████████| 35/35 [00:00<00:00, 130.00it/s]
# Processing BraTS20_Training_294: 100%|██████████| 35/35 [00:00<00:00, 128.13it/s]
# Processing BraTS20_Training_124: 100%|██████████| 35/35 [00:00<00:00, 127.22it/s]
# Processing BraTS20_Training_117: 100%|██████████| 35/35 [00:00<00:00, 128.64it/s]
# Processing BraTS20_Training_365: 100%|██████████| 35/35 [00:00<00:00, 125.76it/s]
# Processing BraTS20_Training_030: 100%|██████████| 35/35 [00:00<00:00, 127.85it/s]
# Processing BraTS20_Training_299: 100%|██████████| 35/35 [00:00<00:00, 113.24it/s]
# Processing BraTS20_Training_209: 100%|██████████| 35/35 [00:00<00:00, 126.76it/s]
# Processing BraTS20_Training_080: 100%|██████████| 35/35 [00:00<00:00, 126.49it/s]
# Processing BraTS20_Training_189: 100%|██████████| 35/35 [00:00<00:00, 126.93it/s]
# Processing BraTS20_Training_314: 100%|██████████| 35/35 [00:00<00:00, 111.27it/s]
# Processing BraTS20_Training_121: 100%|██████████| 35/35 [00:00<00:00, 128.09it/s]
# Processing BraTS20_Training_046: 100%|██████████| 35/35 [00:00<00:00, 131.14it/s]
# Processing BraTS20_Training_196: 100%|██████████| 35/35 [00:00<00:00, 127.23it/s]
# Processing BraTS20_Training_153: 100%|██████████| 35/35 [00:00<00:00, 120.60it/s]
# Processing BraTS20_Training_063: 100%|██████████| 35/35 [00:00<00:00, 124.43it/s]
# Processing BraTS20_Training_210: 100%|██████████| 35/35 [00:00<00:00, 124.52it/s]
# Processing BraTS20_Training_251: 100%|██████████| 35/35 [00:00<00:00, 129.20it/s]
# Processing BraTS20_Training_154: 100%|██████████| 35/35 [00:00<00:00, 132.99it/s]
# Processing BraTS20_Training_125: 100%|██████████| 35/35 [00:00<00:00, 113.69it/s]
# Processing BraTS20_Training_359: 100%|██████████| 35/35 [00:00<00:00, 127.60it/s]
# Processing BraTS20_Training_206: 100%|██████████| 35/35 [00:00<00:00, 129.99it/s]
# Processing BraTS20_Training_185: 100%|██████████| 35/35 [00:00<00:00, 123.19it/s]
# Processing BraTS20_Training_044: 100%|██████████| 35/35 [00:00<00:00, 127.95it/s]
# Processing BraTS20_Training_016: 100%|██████████| 35/35 [00:00<00:00, 127.86it/s]
# Processing BraTS20_Training_115: 100%|██████████| 35/35 [00:00<00:00, 129.73it/s]
# Processing BraTS20_Training_357: 100%|██████████| 35/35 [00:00<00:00, 131.88it/s]
# Processing BraTS20_Training_216: 100%|██████████| 35/35 [00:00<00:00, 109.96it/s]
# Processing BraTS20_Training_341: 100%|██████████| 35/35 [00:00<00:00, 132.74it/s]
# Processing BraTS20_Training_116: 100%|██████████| 35/35 [00:00<00:00, 131.96it/s]
# Processing BraTS20_Training_230: 100%|██████████| 35/35 [00:00<00:00, 129.60it/s]
# Processing BraTS20_Training_090: 100%|██████████| 35/35 [00:00<00:00, 112.52it/s]
# Processing BraTS20_Training_106: 100%|██████████| 35/35 [00:00<00:00, 129.71it/s]
# Processing BraTS20_Training_170: 100%|██████████| 35/35 [00:00<00:00, 125.10it/s]
# Processing BraTS20_Training_309: 100%|██████████| 35/35 [00:00<00:00, 129.10it/s]
# Processing BraTS20_Training_053: 100%|██████████| 35/35 [00:00<00:00, 120.69it/s]
# Processing BraTS20_Training_272: 100%|██████████| 35/35 [00:00<00:00, 123.44it/s]
# Processing BraTS20_Training_202: 100%|██████████| 35/35 [00:00<00:00, 125.69it/s]
# Processing BraTS20_Training_330: 100%|██████████| 35/35 [00:00<00:00, 124.77it/s]
# Processing BraTS20_Training_212: 100%|██████████| 35/35 [00:00<00:00, 123.84it/s]
# Processing BraTS20_Training_122: 100%|██████████| 35/35 [00:00<00:00, 130.23it/s]
# Processing BraTS20_Training_140: 100%|██████████| 35/35 [00:00<00:00, 129.30it/s]
# Processing BraTS20_Training_105: 100%|██████████| 35/35 [00:00<00:00, 129.82it/s]
# Processing BraTS20_Training_332: 100%|██████████| 35/35 [00:00<00:00, 121.23it/s]
# Processing BraTS20_Training_011: 100%|██████████| 35/35 [00:00<00:00, 116.99it/s]
# Processing BraTS20_Training_041: 100%|██████████| 35/35 [00:00<00:00, 133.11it/s]
# Processing BraTS20_Training_138: 100%|██████████| 35/35 [00:00<00:00, 127.53it/s]
# Processing BraTS20_Training_099: 100%|██████████| 35/35 [00:00<00:00, 131.28it/s]
# Processing BraTS20_Training_152: 100%|██████████| 35/35 [00:00<00:00, 130.73it/s]
# Processing BraTS20_Training_300: 100%|██████████| 35/35 [00:00<00:00, 127.49it/s]
# Processing BraTS20_Training_252: 100%|██████████| 35/35 [00:00<00:00, 128.36it/s]
# Processing BraTS20_Training_176: 100%|██████████| 35/35 [00:00<00:00, 126.52it/s]
# Processing BraTS20_Training_040: 100%|██████████| 35/35 [00:00<00:00, 126.68it/s]
# Processing BraTS20_Training_015: 100%|██████████| 35/35 [00:00<00:00, 133.11it/s]
# Processing BraTS20_Training_213: 100%|██████████| 35/35 [00:00<00:00, 129.37it/s]
# Processing BraTS20_Training_312: 100%|██████████| 35/35 [00:00<00:00, 121.85it/s]
# Processing BraTS20_Training_005: 100%|██████████| 35/35 [00:00<00:00, 118.41it/s]
# Processing BraTS20_Training_029: 100%|██████████| 35/35 [00:00<00:00, 125.49it/s]
# Processing BraTS20_Training_271: 100%|██████████| 35/35 [00:00<00:00, 122.56it/s]
# Processing BraTS20_Training_156: 100%|██████████| 35/35 [00:00<00:00, 131.10it/s]
# Processing BraTS20_Training_275: 100%|██████████| 35/35 [00:00<00:00, 124.81it/s]
# Processing BraTS20_Training_147: 100%|██████████| 35/35 [00:00<00:00, 120.78it/s]
# Processing BraTS20_Training_113: 100%|██████████| 35/35 [00:00<00:00, 126.51it/s]
# Processing BraTS20_Training_239: 100%|██████████| 35/35 [00:00<00:00, 130.34it/s]
# Processing BraTS20_Training_329: 100%|██████████| 35/35 [00:00<00:00, 127.05it/s]
# Processing BraTS20_Training_055: 100%|██████████| 35/35 [00:00<00:00, 130.53it/s]
# Processing BraTS20_Training_136: 100%|██████████| 35/35 [00:00<00:00, 126.26it/s]
# Processing BraTS20_Training_208: 100%|██████████| 35/35 [00:00<00:00, 129.26it/s]
# Processing BraTS20_Training_056: 100%|██████████| 35/35 [00:00<00:00, 131.15it/s]
# Processing BraTS20_Training_078: 100%|██████████| 35/35 [00:00<00:00, 122.46it/s]
# Processing BraTS20_Training_001: 100%|██████████| 35/35 [00:00<00:00, 128.28it/s]
# Processing BraTS20_Training_150: 100%|██████████| 35/35 [00:00<00:00, 127.42it/s]
# Processing BraTS20_Training_133: 100%|██████████| 35/35 [00:00<00:00, 127.69it/s]
# Processing BraTS20_Training_109: 100%|██████████| 35/35 [00:00<00:00, 129.51it/s]
# Processing BraTS20_Training_249: 100%|██████████| 35/35 [00:00<00:00, 128.35it/s]
# Processing BraTS20_Training_293: 100%|██████████| 35/35 [00:00<00:00, 121.94it/s]
# Processing BraTS20_Training_311: 100%|██████████| 35/35 [00:00<00:00, 122.12it/s]
# Processing BraTS20_Training_204: 100%|██████████| 35/35 [00:00<00:00, 130.43it/s]
# Processing BraTS20_Training_081: 100%|██████████| 35/35 [00:00<00:00, 115.97it/s]
# Processing BraTS20_Training_159: 100%|██████████| 35/35 [00:00<00:00, 126.50it/s]
# Processing BraTS20_Training_220: 100%|██████████| 35/35 [00:00<00:00, 132.42it/s]
# Processing BraTS20_Training_172: 100%|██████████| 35/35 [00:00<00:00, 134.35it/s]
# Processing BraTS20_Training_287: 100%|██████████| 35/35 [00:00<00:00, 120.53it/s]
# Processing BraTS20_Training_155: 100%|██████████| 35/35 [00:00<00:00, 129.35it/s]
# Processing BraTS20_Training_182: 100%|██████████| 35/35 [00:00<00:00, 81.84it/s]
# Processing BraTS20_Training_353: 100%|██████████| 35/35 [00:00<00:00, 119.50it/s]
# Processing BraTS20_Training_321: 100%|██████████| 35/35 [00:00<00:00, 129.96it/s]
# Processing BraTS20_Training_167: 100%|██████████| 35/35 [00:00<00:00, 122.76it/s]
# Processing BraTS20_Training_086: 100%|██████████| 35/35 [00:00<00:00, 128.19it/s]
# Processing BraTS20_Training_096: 100%|██████████| 35/35 [00:00<00:00, 122.14it/s]
# Processing BraTS20_Training_064: 100%|██████████| 35/35 [00:00<00:00, 120.13it/s]
# Processing BraTS20_Training_326: 100%|██████████| 35/35 [00:00<00:00, 128.48it/s]
# Processing BraTS20_Training_079: 100%|██████████| 35/35 [00:00<00:00, 88.52it/s]
# Processing BraTS20_Training_259: 100%|██████████| 35/35 [00:00<00:00, 132.72it/s]
# Processing BraTS20_Training_092: 100%|██████████| 35/35 [00:00<00:00, 127.31it/s]
# Processing BraTS20_Training_067: 100%|██████████| 35/35 [00:00<00:00, 127.68it/s]
# Processing BraTS20_Training_234: 100%|██████████| 35/35 [00:00<00:00, 120.02it/s]
# Processing BraTS20_Training_022: 100%|██████████| 35/35 [00:00<00:00, 119.13it/s]
# Processing BraTS20_Training_075: 100%|██████████| 35/35 [00:00<00:00, 123.58it/s]
# Processing BraTS20_Training_089: 100%|██████████| 35/35 [00:00<00:00, 129.92it/s]
# Processing BraTS20_Training_254: 100%|██████████| 35/35 [00:00<00:00, 91.58it/s]
# Processing BraTS20_Training_306: 100%|██████████| 35/35 [00:00<00:00, 117.52it/s]
# Processing BraTS20_Training_214: 100%|██████████| 35/35 [00:00<00:00, 124.08it/s]
# Processing BraTS20_Training_247: 100%|██████████| 35/35 [00:00<00:00, 120.66it/s]
# Processing BraTS20_Training_163: 100%|██████████| 35/35 [00:00<00:00, 123.77it/s]
# Processing BraTS20_Training_223: 100%|██████████| 35/35 [00:00<00:00, 129.03it/s]
# Processing BraTS20_Training_295: 100%|██████████| 35/35 [00:00<00:00, 128.82it/s]
# Processing BraTS20_Training_241: 100%|██████████| 35/35 [00:00<00:00, 125.94it/s]
# Processing BraTS20_Training_033: 100%|██████████| 35/35 [00:00<00:00, 122.53it/s]
# Processing BraTS20_Training_250: 100%|██████████| 35/35 [00:00<00:00, 111.61it/s]
# Processing BraTS20_Training_282: 100%|██████████| 35/35 [00:00<00:00, 127.46it/s]
# Processing BraTS20_Training_344: 100%|██████████| 35/35 [00:00<00:00, 131.11it/s]
# Processing BraTS20_Training_102: 100%|██████████| 35/35 [00:00<00:00, 131.22it/s]
# Processing BraTS20_Training_143: 100%|██████████| 35/35 [00:00<00:00, 131.68it/s]
# Processing BraTS20_Training_058: 100%|██████████| 35/35 [00:00<00:00, 126.06it/s]
# Processing BraTS20_Training_123: 100%|██████████| 35/35 [00:00<00:00, 128.77it/s]
# Processing BraTS20_Training_286: 100%|██████████| 35/35 [00:00<00:00, 127.07it/s]
# Processing BraTS20_Training_346: 100%|██████████| 35/35 [00:00<00:00, 124.97it/s]
# Processing BraTS20_Training_093: 100%|██████████| 35/35 [00:00<00:00, 127.77it/s]
# Processing BraTS20_Training_062: 100%|██████████| 35/35 [00:00<00:00, 130.33it/s]
# Processing BraTS20_Training_333: 100%|██████████| 35/35 [00:00<00:00, 131.21it/s]
# Processing BraTS20_Training_094: 100%|██████████| 35/35 [00:00<00:00, 135.14it/s]
# Processing BraTS20_Training_037: 100%|██████████| 35/35 [00:00<00:00, 128.05it/s]
# Processing BraTS20_Training_233: 100%|██████████| 35/35 [00:00<00:00, 127.65it/s]
# Processing BraTS20_Training_351: 100%|██████████| 35/35 [00:00<00:00, 123.22it/s]
# Processing BraTS20_Training_280: 100%|██████████| 35/35 [00:00<00:00, 129.93it/s]
# Processing BraTS20_Training_035: 100%|██████████| 35/35 [00:00<00:00, 121.05it/s]
# Processing BraTS20_Training_057: 100%|██████████| 35/35 [00:00<00:00, 125.87it/s]
# Processing BraTS20_Training_228: 100%|██████████| 35/35 [00:00<00:00, 131.34it/s]
# Processing BraTS20_Training_256: 100%|██████████| 35/35 [00:00<00:00, 119.59it/s]
# Processing BraTS20_Training_188: 100%|██████████| 35/35 [00:00<00:00, 123.45it/s]
# Processing BraTS20_Training_304: 100%|██████████| 35/35 [00:00<00:00, 123.61it/s]
# Processing BraTS20_Training_003: 100%|██████████| 35/35 [00:00<00:00, 106.63it/s]
# Processing BraTS20_Training_023: 100%|██████████| 35/35 [00:00<00:00, 123.42it/s]
# Processing BraTS20_Training_248: 100%|██████████| 35/35 [00:00<00:00, 103.63it/s]
# Processing BraTS20_Training_200: 100%|██████████| 35/35 [00:00<00:00, 116.73it/s]
# Processing BraTS20_Training_184: 100%|██████████| 35/35 [00:00<00:00, 113.25it/s]
# Processing BraTS20_Training_148: 100%|██████████| 35/35 [00:00<00:00, 132.05it/s]
# Processing BraTS20_Training_043: 100%|██████████| 35/35 [00:00<00:00, 130.62it/s]
# Processing BraTS20_Training_319: 100%|██████████| 35/35 [00:00<00:00, 131.67it/s]
# Processing BraTS20_Training_038: 100%|██████████| 35/35 [00:00<00:00, 123.26it/s]
# Processing BraTS20_Training_014: 100%|██████████| 35/35 [00:00<00:00, 120.81it/s]
# Processing BraTS20_Training_267: 100%|██████████| 35/35 [00:00<00:00, 130.14it/s]
# Processing BraTS20_Training_240: 100%|██████████| 35/35 [00:00<00:00, 133.84it/s]
# Processing BraTS20_Training_101: 100%|██████████| 35/35 [00:00<00:00, 128.22it/s]
# Processing BraTS20_Training_068: 100%|██████████| 35/35 [00:00<00:00, 124.78it/s]
# Processing BraTS20_Training_347: 100%|██████████| 35/35 [00:00<00:00, 131.36it/s]
# Processing BraTS20_Training_343: 100%|██████████| 35/35 [00:00<00:00, 128.76it/s]
# Processing BraTS20_Training_175: 100%|██████████| 35/35 [00:00<00:00, 124.83it/s]
# Processing BraTS20_Training_174: 100%|██████████| 35/35 [00:00<00:00, 117.36it/s]
# Processing BraTS20_Training_336: 100%|██████████| 35/35 [00:00<00:00, 125.58it/s]
# Processing BraTS20_Training_192: 100%|██████████| 35/35 [00:00<00:00, 122.38it/s]
# Processing BraTS20_Training_012: 100%|██████████| 35/35 [00:00<00:00, 123.39it/s]
# Processing BraTS20_Training_366: 100%|██████████| 35/35 [00:00<00:00, 123.97it/s]
# Processing BraTS20_Training_315: 100%|██████████| 35/35 [00:00<00:00, 124.80it/s]
# Processing BraTS20_Training_229: 100%|██████████| 35/35 [00:00<00:00, 121.74it/s]
# Processing BraTS20_Training_104: 100%|██████████| 35/35 [00:00<00:00, 129.88it/s]
# Processing BraTS20_Training_032: 100%|██████████| 35/35 [00:00<00:00, 129.66it/s]
# Processing BraTS20_Training_305: 100%|██████████| 35/35 [00:00<00:00, 125.08it/s]
# Processing BraTS20_Training_025: 100%|██████████| 35/35 [00:00<00:00, 125.02it/s]
# Processing BraTS20_Training_071: 100%|██████████| 35/35 [00:00<00:00, 127.04it/s]
# Processing BraTS20_Training_335: 100%|██████████| 35/35 [00:00<00:00, 130.10it/s]
# Processing BraTS20_Training_132: 100%|██████████| 35/35 [00:00<00:00, 119.27it/s]
# Processing BraTS20_Training_066: 100%|██████████| 35/35 [00:00<00:00, 125.19it/s]
# Processing BraTS20_Training_194: 100%|██████████| 35/35 [00:00<00:00, 109.63it/s]
# Processing BraTS20_Training_036: 100%|██████████| 35/35 [00:00<00:00, 123.69it/s]
# Processing BraTS20_Training_349: 100%|██████████| 35/35 [00:00<00:00, 129.12it/s]
# Processing BraTS20_Training_084: 100%|██████████| 35/35 [00:00<00:00, 124.00it/s]
# Processing BraTS20_Training_002: 100%|██████████| 35/35 [00:00<00:00, 126.75it/s]
# Processing BraTS20_Training_211: 100%|██████████| 35/35 [00:00<00:00, 124.13it/s]
# Processing BraTS20_Training_203: 100%|██████████| 35/35 [00:00<00:00, 122.32it/s]
# Processing BraTS20_Training_345: 100%|██████████| 35/35 [00:00<00:00, 126.53it/s]
# Processing BraTS20_Training_128: 100%|██████████| 35/35 [00:00<00:00, 115.82it/s]
# Processing BraTS20_Training_074: 100%|██████████| 35/35 [00:00<00:00, 123.67it/s]
# Processing BraTS20_Training_201: 100%|██████████| 35/35 [00:00<00:00, 126.25it/s]
# Processing BraTS20_Training_193: 100%|██████████| 35/35 [00:00<00:00, 122.06it/s]
# Processing BraTS20_Training_061: 100%|██████████| 35/35 [00:00<00:00, 127.46it/s]
# Processing BraTS20_Training_352: 100%|██████████| 35/35 [00:00<00:00, 126.17it/s]
# Processing BraTS20_Training_088: 100%|██████████| 35/35 [00:00<00:00, 115.24it/s]
# Processing BraTS20_Training_098: 100%|██████████| 35/35 [00:00<00:00, 124.93it/s]
# Processing BraTS20_Training_367: 100%|██████████| 35/35 [00:00<00:00, 125.23it/s]
# Processing BraTS20_Training_242: 100%|██████████| 35/35 [00:00<00:00, 125.09it/s]
# Processing BraTS20_Training_129: 100%|██████████| 35/35 [00:00<00:00, 115.80it/s]
# Processing BraTS20_Training_226: 100%|██████████| 35/35 [00:00<00:00, 103.09it/s]
# Processing BraTS20_Training_137: 100%|██████████| 35/35 [00:00<00:00, 121.99it/s]
# Processing BraTS20_Training_186: 100%|██████████| 35/35 [00:00<00:00, 127.70it/s]
# Processing BraTS20_Training_160: 100%|██████████| 35/35 [00:00<00:00, 129.28it/s]
# Processing BraTS20_Training_199: 100%|██████████| 35/35 [00:00<00:00, 113.58it/s]
# Processing BraTS20_Training_183: 100%|██████████| 35/35 [00:00<00:00, 120.57it/s]
# Processing BraTS20_Training_262: 100%|██████████| 35/35 [00:00<00:00, 129.30it/s]
# Processing BraTS20_Training_298: 100%|██████████| 35/35 [00:00<00:00, 126.71it/s]
# Processing BraTS20_Training_232: 100%|██████████| 35/35 [00:00<00:00, 127.15it/s]
# Processing BraTS20_Training_276: 100%|██████████| 35/35 [00:00<00:00, 123.90it/s]
# Processing BraTS20_Training_171: 100%|██████████| 35/35 [00:00<00:00, 123.08it/s]
# Processing BraTS20_Training_261: 100%|██████████| 35/35 [00:00<00:00, 121.35it/s]
# Processing BraTS20_Training_187: 100%|██████████| 35/35 [00:00<00:00, 122.40it/s]
# Processing BraTS20_Training_021: 100%|██████████| 35/35 [00:00<00:00, 116.66it/s]
# Processing BraTS20_Training_362: 100%|██████████| 35/35 [00:00<00:00, 122.05it/s]
# Processing BraTS20_Training_360: 100%|██████████| 35/35 [00:00<00:00, 120.78it/s]
# Processing BraTS20_Training_103: 100%|██████████| 35/35 [00:00<00:00, 120.86it/s]
# Processing BraTS20_Training_069: 100%|██████████| 35/35 [00:00<00:00, 124.11it/s]
# Processing BraTS20_Training_047: 100%|██████████| 35/35 [00:00<00:00, 124.63it/s]
# Processing BraTS20_Training_168: 100%|██████████| 35/35 [00:00<00:00, 126.59it/s]
# Processing BraTS20_Training_301: 100%|██████████| 35/35 [00:00<00:00, 114.52it/s]
# Processing BraTS20_Training_265: 100%|██████████| 35/35 [00:00<00:00, 128.09it/s]
# Processing BraTS20_Training_130: 100%|██████████| 35/35 [00:00<00:00, 129.82it/s]
# Processing BraTS20_Training_338: 100%|██████████| 35/35 [00:00<00:00, 115.25it/s]
# Processing BraTS20_Training_264: 100%|██████████| 35/35 [00:00<00:00, 119.32it/s]
# Processing BraTS20_Training_237: 100%|██████████| 35/35 [00:00<00:00, 112.72it/s]
# Processing BraTS20_Training_221: 100%|██████████| 35/35 [00:00<00:00, 129.52it/s]
# Processing BraTS20_Training_049: 100%|██████████| 35/35 [00:00<00:00, 131.27it/s]
# Processing BraTS20_Training_191: 100%|██████████| 35/35 [00:00<00:00, 126.11it/s]
# Processing BraTS20_Training_296: 100%|██████████| 35/35 [00:00<00:00, 126.53it/s]
# Processing BraTS20_Training_323: 100%|██████████| 35/35 [00:00<00:00, 129.93it/s]
# Processing BraTS20_Training_059: 100%|██████████| 35/35 [00:00<00:00, 126.55it/s]
# Processing BraTS20_Training_111: 100%|██████████| 35/35 [00:00<00:00, 127.42it/s]
# Processing BraTS20_Training_077: 100%|██████████| 35/35 [00:00<00:00, 126.39it/s]
# Processing BraTS20_Training_020: 100%|██████████| 35/35 [00:00<00:00, 117.78it/s]
# Processing BraTS20_Training_085: 100%|██████████| 35/35 [00:00<00:00, 109.18it/s]
# Processing BraTS20_Training_008: 100%|██████████| 35/35 [00:00<00:00, 124.69it/s]
# Processing BraTS20_Training_134: 100%|██████████| 35/35 [00:00<00:00, 123.64it/s]
# Processing BraTS20_Training_018: 100%|██████████| 35/35 [00:00<00:00, 127.48it/s]
# Processing BraTS20_Training_278: 100%|██████████| 35/35 [00:00<00:00, 128.67it/s]
# Processing BraTS20_Training_291: 100%|██████████| 35/35 [00:00<00:00, 117.08it/s]
# Processing BraTS20_Training_164: 100%|██████████| 35/35 [00:00<00:00, 123.77it/s]
# Processing BraTS20_Training_007: 100%|██████████| 35/35 [00:00<00:00, 115.80it/s]
# Processing BraTS20_Training_013: 100%|██████████| 35/35 [00:00<00:00, 126.28it/s]
# Processing BraTS20_Training_348: 100%|██████████| 35/35 [00:00<00:00, 124.71it/s]
# Processing BraTS20_Training_024: 100%|██████████| 35/35 [00:00<00:00, 130.02it/s]
# Processing BraTS20_Training_087: 100%|██████████| 35/35 [00:00<00:00, 117.20it/s]
# Processing BraTS20_Training_151: 100%|██████████| 35/35 [00:00<00:00, 128.37it/s]
# Processing BraTS20_Training_051: 100%|██████████| 35/35 [00:00<00:00, 126.12it/s]
# Processing BraTS20_Training_224: 100%|██████████| 35/35 [00:00<00:00, 125.34it/s]
# Processing BraTS20_Training_288: 100%|██████████| 35/35 [00:00<00:00, 121.81it/s]
# Processing BraTS20_Training_082: 100%|██████████| 35/35 [00:00<00:00, 127.89it/s]
# Processing BraTS20_Training_190: 100%|██████████| 35/35 [00:00<00:00, 130.18it/s]
# Processing BraTS20_Training_019: 100%|██████████| 35/35 [00:00<00:00, 128.42it/s]
# Processing BraTS20_Training_236: 100%|██████████| 35/35 [00:00<00:00, 119.94it/s]
# Processing BraTS20_Training_325: 100%|██████████| 35/35 [00:00<00:00, 125.28it/s]
# Processing BraTS20_Training_231: 100%|██████████| 35/35 [00:00<00:00, 129.90it/s]
# Processing BraTS20_Training_009: 100%|██████████| 35/35 [00:00<00:00, 123.78it/s]
# Processing BraTS20_Training_369: 100%|██████████| 35/35 [00:00<00:00, 119.39it/s]
# Processing BraTS20_Training_270: 100%|██████████| 35/35 [00:00<00:00, 126.71it/s]
# Processing BraTS20_Training_039: 100%|██████████| 35/35 [00:00<00:00, 131.00it/s]
# Processing BraTS20_Training_327: 100%|██████████| 35/35 [00:00<00:00, 130.40it/s]
# Processing BraTS20_Training_308: 100%|██████████| 35/35 [00:00<00:00, 126.66it/s]
# Processing BraTS20_Training_131: 100%|██████████| 35/35 [00:00<00:00, 127.98it/s]
# Processing BraTS20_Training_340: 100%|██████████| 35/35 [00:00<00:00, 122.90it/s]
# Processing BraTS20_Training_135: 100%|██████████| 35/35 [00:00<00:00, 124.33it/s]
# Processing BraTS20_Training_091: 100%|██████████| 35/35 [00:00<00:00, 112.13it/s]
# Processing BraTS20_Training_165: 100%|██████████| 35/35 [00:00<00:00, 126.68it/s]
# Processing BraTS20_Training_217: 100%|██████████| 35/35 [00:00<00:00, 130.52it/s]
# Processing BraTS20_Training_120: 100%|██████████| 35/35 [00:00<00:00, 130.51it/s]
# Processing BraTS20_Training_139: 100%|██████████| 35/35 [00:00<00:00, 128.36it/s]
# Processing BraTS20_Training_277: 100%|██████████| 35/35 [00:00<00:00, 129.97it/s]
# Processing BraTS20_Training_356: 100%|██████████| 35/35 [00:00<00:00, 126.95it/s]
# Processing BraTS20_Training_269: 100%|██████████| 35/35 [00:00<00:00, 116.81it/s]
# Processing BraTS20_Training_006: 100%|██████████| 35/35 [00:00<00:00, 113.19it/s]
# Processing BraTS20_Training_028: 100%|██████████| 35/35 [00:00<00:00, 122.83it/s]
# Processing BraTS20_Training_017: 100%|██████████| 35/35 [00:00<00:00, 130.58it/s]
# Processing BraTS20_Training_255: 100%|██████████| 35/35 [00:00<00:00, 131.63it/s]
# Processing BraTS20_Training_197: 100%|██████████| 35/35 [00:00<00:00, 122.51it/s]
# Processing BraTS20_Training_144: 100%|██████████| 35/35 [00:00<00:00, 132.00it/s]
# Processing BraTS20_Training_313: 100%|██████████| 35/35 [00:00<00:00, 128.59it/s]
# Processing BraTS20_Training_112: 100%|██████████| 35/35 [00:00<00:00, 127.19it/s]
# Processing BraTS20_Training_283: 100%|██████████| 35/35 [00:00<00:00, 112.19it/s]
# Processing BraTS20_Training_050: 100%|██████████| 35/35 [00:00<00:00, 129.59it/s]
# Processing BraTS20_Training_149: 100%|██████████| 35/35 [00:00<00:00, 130.86it/s]
# Processing BraTS20_Training_072: 100%|██████████| 35/35 [00:00<00:00, 128.69it/s]
# Processing BraTS20_Training_118: 100%|██████████| 35/35 [00:00<00:00, 129.87it/s]
# Processing BraTS20_Training_260: 100%|██████████| 35/35 [00:00<00:00, 123.28it/s]
# Processing BraTS20_Training_290: 100%|██████████| 35/35 [00:00<00:00, 120.08it/s]
# Processing BraTS20_Training_042: 100%|██████████| 35/35 [00:00<00:00, 128.97it/s]
# Processing BraTS20_Training_177: 100%|██████████| 35/35 [00:00<00:00, 129.82it/s]
# Processing BraTS20_Training_126: 100%|██████████| 35/35 [00:00<00:00, 126.50it/s]
# Processing BraTS20_Training_317: 100%|██████████| 35/35 [00:00<00:00, 119.91it/s]
# Processing BraTS20_Training_246: 100%|██████████| 35/35 [00:00<00:00, 126.83it/s]
# Processing BraTS20_Training_181: 100%|██████████| 35/35 [00:00<00:00, 121.83it/s]
# Processing BraTS20_Training_178: 100%|██████████| 35/35 [00:00<00:00, 127.57it/s]
# Processing BraTS20_Training_285: 100%|██████████| 35/35 [00:00<00:00, 131.36it/s]
# Processing BraTS20_Training_297: 100%|██████████| 35/35 [00:00<00:00, 108.73it/s]
# Preprocessing and saving completed successfully!

# %%
# Define the paths to the saved train and validation data
train_images_path = "/kaggle/working/train_data/images"
train_masks_path = "/kaggle/working/train_data/masks"
val_images_path = "/kaggle/working/val_data/images"
val_masks_path = "/kaggle/working/val_data/masks"

# Count the total number of images in train and val sets
num_train_images = len(os.listdir(train_images_path))
num_val_images = len(os.listdir(val_images_path))

print(f"Number of training images: {num_train_images}")
print(f"Number of validation images: {num_val_images}")
# Out:
# Number of training images: 10290
# Number of validation images: 2590

# %%
import random
def visualize_samples(images_path, masks_path, num_samples=5, num_classes=4):
    image_files = sorted(os.listdir(images_path))
    mask_files = sorted(os.listdir(masks_path))

    random_indices = random.sample(range(len(image_files)), num_samples)

    plt.figure(figsize=(15, num_samples * 3))
    for i, idx in enumerate(random_indices):
        # Load image and mask
        img = np.load(os.path.join(images_path, image_files[idx]))
        mask = np.load(os.path.join(masks_path, mask_files[idx]))

        # Convert mask back to single-channel for visualization
        mask_single_channel = np.argmax(mask, axis=-1)

        # Plot image and mask
        plt.subplot(num_samples, 2, 2 * i + 1)
        plt.imshow(img[:, :, 0], cmap='gray')  # Display the first modality
        plt.title(f"Image: {image_files[idx]}")
        plt.axis("off")

        plt.subplot(num_samples, 2, 2 * i + 2)
        plt.imshow(mask_single_channel, cmap='viridis')
        plt.title(f"Mask: {mask_files[idx]}")
        plt.axis("off")

    plt.tight_layout()
    plt.show()

# Visualize random training samples
print("Visualizing training samples:")
visualize_samples(train_images_path, train_masks_path, num_samples=5)

# Visualize random validation samples
print("Visualizing validation samples:")
visualize_samples(val_images_path, val_masks_path, num_samples=5)
# Out:
# Visualizing training samples:
# Visualizing validation samples:

# %%
from tensorflow.keras.utils import Sequence

class BrainTumorDataGenerator(Sequence):
    def __init__(self, images_path, masks_path, batch_size=16, shuffle=True):
        self.images_path = images_path
        self.masks_path = masks_path
        self.batch_size = batch_size
        self.shuffle = shuffle
        self.image_files = sorted(os.listdir(images_path))
        self.mask_files = sorted(os.listdir(masks_path))
        self.on_epoch_end()

    def __len__(self):
        """Number of batches per epoch."""
        return int(np.floor(len(self.image_files) / self.batch_size))

    def __getitem__(self, index):
        """Generate one batch of data."""
        batch_image_files = self.image_files[index * self.batch_size:(index + 1) * self.batch_size]
        batch_mask_files = self.mask_files[index * self.batch_size:(index + 1) * self.batch_size]

        images, masks = self.__load_batch(batch_image_files, batch_mask_files)
        return np.array(images), np.array(masks)

    def __load_batch(self, batch_image_files, batch_mask_files):
        """Load a batch of images and masks."""
        images = []
        masks = []

        for img_file, mask_file in zip(batch_image_files, batch_mask_files):
            img = np.load(os.path.join(self.images_path, img_file))
            mask = np.load(os.path.join(self.masks_path, mask_file))
            images.append(img)
            masks.append(mask)

        return images, masks

    def on_epoch_end(self):
        """Shuffle data at the end of each epoch."""
        if self.shuffle:
            combined = list(zip(self.image_files, self.mask_files))
            random.shuffle(combined)
            self.image_files, self.mask_files = zip(*combined)

# Initialize data generators
batch_size = 16
train_generator = BrainTumorDataGenerator(train_images_path, train_masks_path, batch_size=batch_size)
val_generator = BrainTumorDataGenerator(val_images_path, val_masks_path, batch_size=batch_size, shuffle=False)

# %%
import tensorflow.keras.backend as K

def weighted_dice_loss(y_true, y_pred, class_weights):
    """Weighted Dice Loss for imbalanced classes."""
    smooth = 1e-6
    y_true = K.cast(y_true, 'float32')
    y_pred = K.cast(y_pred, 'float32')

    intersection = K.sum(y_true * y_pred, axis=[1, 2])
    union = K.sum(y_true + y_pred, axis=[1, 2])

    dice = (2.0 * intersection + smooth) / (union + smooth)
    weighted_dice = -K.sum(class_weights * dice, axis=-1)
    return K.mean(weighted_dice)

# Example class weights (adjust based on your dataset):
class_weights = np.array([0.45, 0.25, 0.20, 0.20])  # Equal weights for all

# %%
import tensorflow as tf
from tensorflow.keras import backend as K

def dice_coef(y_true, y_pred, smooth=1.0):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    intersection = K.sum(y_true * y_pred, axis=(1, 2, 3))
    return K.mean((2. * intersection + smooth) / 
                  (K.sum(y_true, axis=(1, 2, 3)) + K.sum(y_pred, axis=(1, 2, 3)) + smooth))
def dice_coef_necrotic(y_true, y_pred, epsilon=1e-6):
    y_true = K.cast(y_true, y_pred.dtype)  # Cast y_true to the same dtype as y_pred
    y_true_necrotic = y_true[..., 1]  # Class 1: NECROTIC/CORE
    y_pred_necrotic = y_pred[..., 1]
    intersection = K.sum(K.abs(y_true_necrotic * y_pred_necrotic))
    return (2. * intersection) / (K.sum(K.square(y_true_necrotic)) + K.sum(K.square(y_pred_necrotic)) + epsilon)

def dice_coef_edema(y_true, y_pred, epsilon=1e-6):
    y_true = K.cast(y_true, y_pred.dtype)  # Cast y_true to the same dtype as y_pred
    y_true_edema = y_true[..., 2]  # Class 2: EDEMA
    y_pred_edema = y_pred[..., 2]
    intersection = K.sum(K.abs(y_true_edema * y_pred_edema))
    return (2. * intersection) / (K.sum(K.square(y_true_edema)) + K.sum(K.square(y_pred_edema)) + epsilon)

def dice_coef_enhancing(y_true, y_pred, epsilon=1e-6):
    y_true = K.cast(y_true, y_pred.dtype)  # Cast y_true to the same dtype as y_pred
    y_true_enhancing = y_true[..., 3]  # Class 3: ENHANCING
    y_pred_enhancing = y_pred[..., 3]
    intersection = K.sum(K.abs(y_true_enhancing * y_pred_enhancing))
    return (2. * intersection) / (K.sum(K.square(y_true_enhancing)) + K.sum(K.square(y_pred_enhancing)) + epsilon)

def precision(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    return true_positives / (predicted_positives + K.epsilon())

def sensitivity(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    return true_positives / (possible_positives + K.epsilon())

def specificity(y_true, y_pred):
    y_true = tf.cast(y_true, tf.float32)
    y_pred = tf.cast(y_pred, tf.float32)
    true_negatives = K.sum(K.round(K.clip((1 - y_true) * (1 - y_pred), 0, 1)))
    possible_negatives = K.sum(K.round(K.clip(1 - y_true, 0, 1)))
    return true_negatives / (possible_negatives + K.epsilon())

# %%
# Import Necessary Libraries
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.layers import Input, Conv2D, Dropout, BatchNormalization, UpSampling2D, concatenate
from tensorflow.keras.models import Model

# Define the Simplified U-Net Model Architecture
def build_unet(input_shape=(128, 128, 3), num_classes=4):
    inputs = Input(input_shape)
    
    # Encoder: Using EfficientNetB0 as a Backbone
    base_model = EfficientNetB0(include_top=False, weights='imagenet', input_tensor=inputs)
    
    # Extract Encoder Outputs for Skip Connections
    skip1 = base_model.get_layer('block2a_expand_activation').output  # 64x64
    skip2 = base_model.get_layer('block3a_expand_activation').output  # 32x32
    skip3 = base_model.get_layer('block4a_expand_activation').output  # 16x16
    skip4 = base_model.get_layer('block6a_expand_activation').output  # 8x8
    
    # Bottleneck
    x = base_model.output  # 4x4
    
    # Decoder: Manually Implemented Layers (No Loops)
    # 1st Decoder Block
    x = UpSampling2D()(x)  # Upsample 4x4 -> 8x8
    x = concatenate([x, skip4])  # Add Skip Connection
    x = Conv2D(256, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # 2nd Decoder Block
    x = UpSampling2D()(x)  # Upsample 8x8 -> 16x16
    x = concatenate([x, skip3])  # Add Skip Connection
    x = Conv2D(128, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # 3rd Decoder Block
    x = UpSampling2D()(x)  # Upsample 16x16 -> 32x32
    x = concatenate([x, skip2])  # Add Skip Connection
    x = Conv2D(64, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # 4th Decoder Block
    x = UpSampling2D()(x)  # Upsample 32x32 -> 64x64
    x = concatenate([x, skip1])  # Add Skip Connection
    x = Conv2D(32, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # Final Upsampling to Match Input Resolution
    x = UpSampling2D()(x)  # Upsample 64x64 -> 128x128
    x = Conv2D(16, (3, 3), activation='relu', padding='same')(x)
    x = BatchNormalization()(x)
    x = Dropout(0.2)(x)

    # Output Layer
    outputs = Conv2D(num_classes, (1, 1), activation='softmax')(x)  # Final Segmentation Map
    
    # Define the Model
    model = Model(inputs=[inputs], outputs=[outputs])
    return model

# Create the U-Net Model
input_shape = (128, 128, 3)  # Define your input shape here
num_classes = 4  # Define the number of classes for your segmentation task
model = build_unet(input_shape, num_classes)
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
strategy = tf.distribute.MirroredStrategy()

# %%
with strategy.scope():
    model = build_unet(input_shape=(128, 128, 3), num_classes=4)  # Your U-Net model
    model.compile(
        optimizer='adam',
        loss=lambda y_true, y_pred: weighted_dice_loss(y_true, y_pred, class_weights),
        metrics=['accuracy',dice_coef]
    )

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau

lr_scheduler = ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, verbose=1, min_lr=1e-6)

# %%
print(f"Number of devices: {strategy.num_replicas_in_sync}")
# Out:
# Number of devices: 2

# %%
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
import matplotlib.pyplot as plt

# Define the callback to save the best model
checkpoint = ModelCheckpoint(
    "/kaggle/working/best_model.keras", 
    monitor="val_loss", 
    save_best_only=True, 
    mode="min", 
    verbose=1
)

# Learning rate scheduler
lr_scheduler = ReduceLROnPlateau(
    monitor="val_loss", 
    factor=0.5, 
    patience=3, 
    verbose=1, 
    min_lr=1e-6
)

#model.compile(optimizer='adam', loss=lambda y_true, y_pred: weighted_dice_loss(y_true, y_pred, class_weights), metrics=['accuracy'])
print(f"Number of devices: {strategy.num_replicas_in_sync}")


history = model.fit(
        train_generator,
        validation_data=val_generator,
        epochs=30,
        callbacks=[checkpoint, lr_scheduler]
        
    )
# Out:
# Number of devices: 2
# Epoch 1/30
# 2024-12-17 03:27:48.956579: E tensorflow/core/grappler/optimizers/meta_optimizer.cc:961] layout failed: INVALID_ARGUMENT: Size of values 0 does not match size of permutation 4 @ fanin shape inStatefulPartitionedCall/cond/else/_1706/cond/StatefulPartitionedCall/functional_3_1/block2b_drop_1/stateless_dropout/SelectV2-2-TransposeNHWCToNCHW-LayoutOptimizer
# /opt/conda/lib/python3.10/site-packages/keras/src/trainers/data_adapters/py_dataset_adapter.py:121: UserWarning: Your `PyDataset` class should call `super().__init__(**kwargs)` in its constructor. `**kwargs` can include `workers`, `use_multiprocessing`, `max_queue_size`. Do not pass these arguments to `fit()`, as they will be ignored.
#   self._warn_if_super_not_called()
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 181ms/step - accuracy: 0.7331 - dice_coef: 0.6924 - loss: -0.4787
# Epoch 1: val_loss improved from inf to -0.50653, saving model to /kaggle/working/best_model.keras
# /opt/conda/lib/python3.10/site-packages/keras/src/saving/serialization_lib.py:390: UserWarning: The object being serialized includes a `lambda`. This is unsafe. In order to reload the object, you will have to pass `safe_mode=False` to the loading function. Please avoid using `lambda` in the future, and use named Python functions instead. This is the `lambda` being serialized:         loss=lambda y_true, y_pred: weighted_dice_loss(y_true, y_pred, class_weights),
#
#   return {key: serialize_keras_object(value) for key, value in obj.items()}
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 265s 204ms/step - accuracy: 0.7332 - dice_coef: 0.6926 - loss: -0.4788 - val_accuracy: 0.9566 - val_dice_coef: 0.9543 - val_loss: -0.5065 - learning_rate: 0.0010
# Epoch 2/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9792 - dice_coef: 0.9781 - loss: -0.6719
# Epoch 2: val_loss improved from -0.50653 to -0.67230, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 119s 185ms/step - accuracy: 0.9792 - dice_coef: 0.9781 - loss: -0.6720 - val_accuracy: 0.9783 - val_dice_coef: 0.9782 - val_loss: -0.6723 - learning_rate: 0.0010
# Epoch 3/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9838 - dice_coef: 0.9837 - loss: -0.6951
# Epoch 3: val_loss improved from -0.67230 to -0.68390, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 119s 185ms/step - accuracy: 0.9838 - dice_coef: 0.9837 - loss: -0.6950 - val_accuracy: 0.9759 - val_dice_coef: 0.9758 - val_loss: -0.6839 - learning_rate: 0.0010
# Epoch 4/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9848 - dice_coef: 0.9847 - loss: -0.7051
# Epoch 4: val_loss improved from -0.68390 to -0.68590, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9848 - dice_coef: 0.9847 - loss: -0.7051 - val_accuracy: 0.9786 - val_dice_coef: 0.9786 - val_loss: -0.6859 - learning_rate: 0.0010
# Epoch 5/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9864 - dice_coef: 0.9863 - loss: -0.7135
# Epoch 5: val_loss improved from -0.68590 to -0.70479, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9864 - dice_coef: 0.9863 - loss: -0.7135 - val_accuracy: 0.9859 - val_dice_coef: 0.9859 - val_loss: -0.7048 - learning_rate: 0.0010
# Epoch 6/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9895 - dice_coef: 0.9895 - loss: -0.7274
# Epoch 6: val_loss improved from -0.70479 to -0.71586, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9896 - dice_coef: 0.9895 - loss: -0.7274 - val_accuracy: 0.9820 - val_dice_coef: 0.9819 - val_loss: -0.7159 - learning_rate: 0.0010
# Epoch 7/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9896 - dice_coef: 0.9895 - loss: -0.7305
# Epoch 7: val_loss did not improve from -0.71586
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 116s 181ms/step - accuracy: 0.9896 - dice_coef: 0.9895 - loss: -0.7305 - val_accuracy: 0.9858 - val_dice_coef: 0.9858 - val_loss: -0.7066 - learning_rate: 0.0010
# Epoch 8/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.7340
# Epoch 8: val_loss improved from -0.71586 to -0.72343, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.7340 - val_accuracy: 0.9877 - val_dice_coef: 0.9877 - val_loss: -0.7234 - learning_rate: 0.0010
# Epoch 9/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.7373
# Epoch 9: val_loss did not improve from -0.72343
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.7373 - val_accuracy: 0.9862 - val_dice_coef: 0.9862 - val_loss: -0.7188 - learning_rate: 0.0010
# Epoch 10/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9904 - dice_coef: 0.9904 - loss: -0.7409
# Epoch 10: val_loss improved from -0.72343 to -0.73203, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9904 - dice_coef: 0.9904 - loss: -0.7409 - val_accuracy: 0.9870 - val_dice_coef: 0.9870 - val_loss: -0.7320 - learning_rate: 0.0010
# Epoch 11/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9907 - dice_coef: 0.9907 - loss: -0.7424
# Epoch 11: val_loss improved from -0.73203 to -0.73691, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9907 - dice_coef: 0.9907 - loss: -0.7424 - val_accuracy: 0.9861 - val_dice_coef: 0.9861 - val_loss: -0.7369 - learning_rate: 0.0010
# Epoch 12/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9906 - dice_coef: 0.9906 - loss: -0.7489
# Epoch 12: val_loss did not improve from -0.73691
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 181ms/step - accuracy: 0.9906 - dice_coef: 0.9906 - loss: -0.7489 - val_accuracy: 0.9860 - val_dice_coef: 0.9859 - val_loss: -0.7163 - learning_rate: 0.0010
# Epoch 13/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9880 - dice_coef: 0.9880 - loss: -0.7823
# Epoch 13: val_loss did not improve from -0.73691
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 116s 180ms/step - accuracy: 0.9880 - dice_coef: 0.9880 - loss: -0.7822 - val_accuracy: 0.9852 - val_dice_coef: 0.9852 - val_loss: -0.7210 - learning_rate: 0.0010
# Epoch 14/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9881 - dice_coef: 0.9881 - loss: -0.8032
# Epoch 14: val_loss improved from -0.73691 to -0.75475, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9881 - dice_coef: 0.9881 - loss: -0.8032 - val_accuracy: 0.9823 - val_dice_coef: 0.9823 - val_loss: -0.7548 - learning_rate: 0.0010
# Epoch 15/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9872 - dice_coef: 0.9872 - loss: -0.8625
# Epoch 15: val_loss improved from -0.75475 to -0.82794, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9872 - dice_coef: 0.9872 - loss: -0.8625 - val_accuracy: 0.9855 - val_dice_coef: 0.9855 - val_loss: -0.8279 - learning_rate: 0.0010
# Epoch 16/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9882 - dice_coef: 0.9882 - loss: -0.8819
# Epoch 16: val_loss improved from -0.82794 to -0.86408, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9882 - dice_coef: 0.9882 - loss: -0.8819 - val_accuracy: 0.9873 - val_dice_coef: 0.9873 - val_loss: -0.8641 - learning_rate: 0.0010
# Epoch 17/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9878 - dice_coef: 0.9878 - loss: -0.8707
# Epoch 17: val_loss did not improve from -0.86408
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 181ms/step - accuracy: 0.9878 - dice_coef: 0.9878 - loss: -0.8707 - val_accuracy: 0.9861 - val_dice_coef: 0.9861 - val_loss: -0.8593 - learning_rate: 0.0010
# Epoch 18/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9886 - dice_coef: 0.9886 - loss: -0.8860
# Epoch 18: val_loss did not improve from -0.86408
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9886 - dice_coef: 0.9886 - loss: -0.8860 - val_accuracy: 0.9816 - val_dice_coef: 0.9816 - val_loss: -0.7629 - learning_rate: 0.0010
# Epoch 19/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9887 - dice_coef: 0.9887 - loss: -0.8833
# Epoch 19: val_loss did not improve from -0.86408
#
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9887 - dice_coef: 0.9887 - loss: -0.8833 - val_accuracy: 0.9849 - val_dice_coef: 0.9849 - val_loss: -0.8452 - learning_rate: 0.0010
# Epoch 20/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9888 - dice_coef: 0.9888 - loss: -0.8870
# Epoch 20: val_loss improved from -0.86408 to -0.87158, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9888 - dice_coef: 0.9888 - loss: -0.8870 - val_accuracy: 0.9872 - val_dice_coef: 0.9872 - val_loss: -0.8716 - learning_rate: 5.0000e-04
# Epoch 21/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step - accuracy: 0.9889 - dice_coef: 0.9889 - loss: -0.8916
# Epoch 21: val_loss did not improve from -0.87158
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 181ms/step - accuracy: 0.9889 - dice_coef: 0.9889 - loss: -0.8916 - val_accuracy: 0.9869 - val_dice_coef: 0.9869 - val_loss: -0.8573 - learning_rate: 5.0000e-04
# Epoch 22/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9893 - dice_coef: 0.9893 - loss: -0.8983
# Epoch 22: val_loss improved from -0.87158 to -0.87913, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 119s 184ms/step - accuracy: 0.9893 - dice_coef: 0.9893 - loss: -0.8983 - val_accuracy: 0.9875 - val_dice_coef: 0.9875 - val_loss: -0.8791 - learning_rate: 5.0000e-04
# Epoch 23/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 176ms/step - accuracy: 0.9899 - dice_coef: 0.9899 - loss: -0.9039
# Epoch 23: val_loss did not improve from -0.87913
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 183ms/step - accuracy: 0.9899 - dice_coef: 0.9899 - loss: -0.9039 - val_accuracy: 0.9876 - val_dice_coef: 0.9876 - val_loss: -0.8788 - learning_rate: 5.0000e-04
# Epoch 24/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9899 - dice_coef: 0.9899 - loss: -0.9076
# Epoch 24: val_loss did not improve from -0.87913
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9899 - dice_coef: 0.9899 - loss: -0.9076 - val_accuracy: 0.9874 - val_dice_coef: 0.9874 - val_loss: -0.8785 - learning_rate: 5.0000e-04
# Epoch 25/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9066
# Epoch 25: val_loss improved from -0.87913 to -0.88142, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9066 - val_accuracy: 0.9882 - val_dice_coef: 0.9882 - val_loss: -0.8814 - learning_rate: 5.0000e-04
# Epoch 26/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9132
# Epoch 26: val_loss improved from -0.88142 to -0.88236, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 118s 184ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9132 - val_accuracy: 0.9880 - val_dice_coef: 0.9880 - val_loss: -0.8824 - learning_rate: 5.0000e-04
# Epoch 27/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9139
# Epoch 27: val_loss did not improve from -0.88236
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9139 - val_accuracy: 0.9860 - val_dice_coef: 0.9860 - val_loss: -0.8649 - learning_rate: 5.0000e-04
# Epoch 28/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9901 - dice_coef: 0.9901 - loss: -0.9100
# Epoch 28: val_loss did not improve from -0.88236
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 116s 181ms/step - accuracy: 0.9901 - dice_coef: 0.9901 - loss: -0.9100 - val_accuracy: 0.9878 - val_dice_coef: 0.9878 - val_loss: -0.8783 - learning_rate: 5.0000e-04
# Epoch 29/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9113
# Epoch 29: val_loss did not improve from -0.88236
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 117s 182ms/step - accuracy: 0.9902 - dice_coef: 0.9902 - loss: -0.9113 - val_accuracy: 0.9875 - val_dice_coef: 0.9875 - val_loss: -0.8777 - learning_rate: 5.0000e-04
# Epoch 30/30
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 0s 174ms/step - accuracy: 0.9903 - dice_coef: 0.9903 - loss: -0.9153
# Epoch 30: val_loss improved from -0.88236 to -0.88571, saving model to /kaggle/working/best_model.keras
# 643/643 ━━━━━━━━━━━━━━━━━━━━ 119s 185ms/step - accuracy: 0.9903 - dice_coef: 0.9903 - loss: -0.9153 - val_accuracy: 0.9882 - val_dice_coef: 0.9882 - val_loss: -0.8857 - learning_rate: 2.5000e-04

# %%
model.summary()
# Out:
# Model: "functional_3"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_2         │ (None, 128, 128,  │          0 │ input_layer_1[0]… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ normalization_1     │ (None, 128, 128,  │          7 │ rescaling_2[0][0] │
# │ (Normalization)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ rescaling_3         │ (None, 128, 128,  │          0 │ normalization_1[… │
# │ (Rescaling)         │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv_pad       │ (None, 129, 129,  │          0 │ rescaling_3[0][0] │
# │ (ZeroPadding2D)     │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_conv (Conv2D)  │ (None, 64, 64,    │        864 │ stem_conv_pad[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_bn             │ (None, 64, 64,    │        128 │ stem_conv[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ stem_activation     │ (None, 64, 64,    │          0 │ stem_bn[0][0]     │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_dwconv      │ (None, 64, 64,    │        288 │ stem_activation[… │
# │ (DepthwiseConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_bn          │ (None, 64, 64,    │        128 │ block1a_dwconv[0… │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_activation  │ (None, 64, 64,    │          0 │ block1a_bn[0][0]  │
# │ (Activation)        │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_squeeze  │ (None, 32)        │          0 │ block1a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reshape  │ (None, 1, 1, 32)  │          0 │ block1a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_reduce   │ (None, 1, 1, 8)   │        264 │ block1a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_expand   │ (None, 1, 1, 32)  │        288 │ block1a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_se_excite   │ (None, 64, 64,    │          0 │ block1a_activati… │
# │ (Multiply)          │ 32)               │            │ block1a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_co… │ (None, 64, 64,    │        512 │ block1a_se_excit… │
# │ (Conv2D)            │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block1a_project_bn  │ (None, 64, 64,    │         64 │ block1a_project_… │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_conv │ (None, 64, 64,    │      1,536 │ block1a_project_… │
# │ (Conv2D)            │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_bn   │ (None, 64, 64,    │        384 │ block2a_expand_c… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_expand_act… │ (None, 64, 64,    │          0 │ block2a_expand_b… │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv_pad  │ (None, 65, 65,    │          0 │ block2a_expand_a… │
# │ (ZeroPadding2D)     │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_dwconv      │ (None, 32, 32,    │        864 │ block2a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_bn          │ (None, 32, 32,    │        384 │ block2a_dwconv[0… │
# │ (BatchNormalizatio… │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_activation  │ (None, 32, 32,    │          0 │ block2a_bn[0][0]  │
# │ (Activation)        │ 96)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_squeeze  │ (None, 96)        │          0 │ block2a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reshape  │ (None, 1, 1, 96)  │          0 │ block2a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_reduce   │ (None, 1, 1, 4)   │        388 │ block2a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_expand   │ (None, 1, 1, 96)  │        480 │ block2a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_se_excite   │ (None, 32, 32,    │          0 │ block2a_activati… │
# │ (Multiply)          │ 96)               │            │ block2a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_co… │ (None, 32, 32,    │      2,304 │ block2a_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2a_project_bn  │ (None, 32, 32,    │         96 │ block2a_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_conv │ (None, 32, 32,    │      3,456 │ block2a_project_… │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_bn   │ (None, 32, 32,    │        576 │ block2b_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_expand_act… │ (None, 32, 32,    │          0 │ block2b_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_dwconv      │ (None, 32, 32,    │      1,296 │ block2b_expand_a… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_bn          │ (None, 32, 32,    │        576 │ block2b_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_activation  │ (None, 32, 32,    │          0 │ block2b_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_squeeze  │ (None, 144)       │          0 │ block2b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reshape  │ (None, 1, 1, 144) │          0 │ block2b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_reduce   │ (None, 1, 1, 6)   │        870 │ block2b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_expand   │ (None, 1, 1, 144) │      1,008 │ block2b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_se_excite   │ (None, 32, 32,    │          0 │ block2b_activati… │
# │ (Multiply)          │ 144)              │            │ block2b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_co… │ (None, 32, 32,    │      3,456 │ block2b_se_excit… │
# │ (Conv2D)            │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_project_bn  │ (None, 32, 32,    │         96 │ block2b_project_… │
# │ (BatchNormalizatio… │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_drop        │ (None, 32, 32,    │          0 │ block2b_project_… │
# │ (Dropout)           │ 24)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block2b_add (Add)   │ (None, 32, 32,    │          0 │ block2b_drop[0][… │
# │                     │ 24)               │            │ block2a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_conv │ (None, 32, 32,    │      3,456 │ block2b_add[0][0] │
# │ (Conv2D)            │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_bn   │ (None, 32, 32,    │        576 │ block3a_expand_c… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_expand_act… │ (None, 32, 32,    │          0 │ block3a_expand_b… │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv_pad  │ (None, 35, 35,    │          0 │ block3a_expand_a… │
# │ (ZeroPadding2D)     │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_dwconv      │ (None, 16, 16,    │      3,600 │ block3a_dwconv_p… │
# │ (DepthwiseConv2D)   │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_bn          │ (None, 16, 16,    │        576 │ block3a_dwconv[0… │
# │ (BatchNormalizatio… │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_activation  │ (None, 16, 16,    │          0 │ block3a_bn[0][0]  │
# │ (Activation)        │ 144)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_squeeze  │ (None, 144)       │          0 │ block3a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reshape  │ (None, 1, 1, 144) │          0 │ block3a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_reduce   │ (None, 1, 1, 6)   │        870 │ block3a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_expand   │ (None, 1, 1, 144) │      1,008 │ block3a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_se_excite   │ (None, 16, 16,    │          0 │ block3a_activati… │
# │ (Multiply)          │ 144)              │            │ block3a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_co… │ (None, 16, 16,    │      5,760 │ block3a_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3a_project_bn  │ (None, 16, 16,    │        160 │ block3a_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_conv │ (None, 16, 16,    │      9,600 │ block3a_project_… │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_bn   │ (None, 16, 16,    │        960 │ block3b_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_expand_act… │ (None, 16, 16,    │          0 │ block3b_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_dwconv      │ (None, 16, 16,    │      6,000 │ block3b_expand_a… │
# │ (DepthwiseConv2D)   │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_bn          │ (None, 16, 16,    │        960 │ block3b_dwconv[0… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_activation  │ (None, 16, 16,    │          0 │ block3b_bn[0][0]  │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_squeeze  │ (None, 240)       │          0 │ block3b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reshape  │ (None, 1, 1, 240) │          0 │ block3b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block3b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_expand   │ (None, 1, 1, 240) │      2,640 │ block3b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_se_excite   │ (None, 16, 16,    │          0 │ block3b_activati… │
# │ (Multiply)          │ 240)              │            │ block3b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_co… │ (None, 16, 16,    │      9,600 │ block3b_se_excit… │
# │ (Conv2D)            │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_project_bn  │ (None, 16, 16,    │        160 │ block3b_project_… │
# │ (BatchNormalizatio… │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_drop        │ (None, 16, 16,    │          0 │ block3b_project_… │
# │ (Dropout)           │ 40)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block3b_add (Add)   │ (None, 16, 16,    │          0 │ block3b_drop[0][… │
# │                     │ 40)               │            │ block3a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_conv │ (None, 16, 16,    │      9,600 │ block3b_add[0][0] │
# │ (Conv2D)            │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_bn   │ (None, 16, 16,    │        960 │ block4a_expand_c… │
# │ (BatchNormalizatio… │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_expand_act… │ (None, 16, 16,    │          0 │ block4a_expand_b… │
# │ (Activation)        │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv_pad  │ (None, 17, 17,    │          0 │ block4a_expand_a… │
# │ (ZeroPadding2D)     │ 240)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_dwconv      │ (None, 8, 8, 240) │      2,160 │ block4a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_bn          │ (None, 8, 8, 240) │        960 │ block4a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_activation  │ (None, 8, 8, 240) │          0 │ block4a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_squeeze  │ (None, 240)       │          0 │ block4a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reshape  │ (None, 1, 1, 240) │          0 │ block4a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_reduce   │ (None, 1, 1, 10)  │      2,410 │ block4a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_expand   │ (None, 1, 1, 240) │      2,640 │ block4a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_se_excite   │ (None, 8, 8, 240) │          0 │ block4a_activati… │
# │ (Multiply)          │                   │            │ block4a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_co… │ (None, 8, 8, 80)  │     19,200 │ block4a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4a_project_bn  │ (None, 8, 8, 80)  │        320 │ block4a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block4b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_expand_act… │ (None, 8, 8, 480) │          0 │ block4b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_dwconv      │ (None, 8, 8, 480) │      4,320 │ block4b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_bn          │ (None, 8, 8, 480) │      1,920 │ block4b_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_activation  │ (None, 8, 8, 480) │          0 │ block4b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_squeeze  │ (None, 480)       │          0 │ block4b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reshape  │ (None, 1, 1, 480) │          0 │ block4b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_se_excite   │ (None, 8, 8, 480) │          0 │ block4b_activati… │
# │ (Multiply)          │                   │            │ block4b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_co… │ (None, 8, 8, 80)  │     38,400 │ block4b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_project_bn  │ (None, 8, 8, 80)  │        320 │ block4b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_drop        │ (None, 8, 8, 80)  │          0 │ block4b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4b_add (Add)   │ (None, 8, 8, 80)  │          0 │ block4b_drop[0][… │
# │                     │                   │            │ block4a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block4c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_expand_act… │ (None, 8, 8, 480) │          0 │ block4c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_dwconv      │ (None, 8, 8, 480) │      4,320 │ block4c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_bn          │ (None, 8, 8, 480) │      1,920 │ block4c_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_activation  │ (None, 8, 8, 480) │          0 │ block4c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_squeeze  │ (None, 480)       │          0 │ block4c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reshape  │ (None, 1, 1, 480) │          0 │ block4c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block4c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_expand   │ (None, 1, 1, 480) │     10,080 │ block4c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_se_excite   │ (None, 8, 8, 480) │          0 │ block4c_activati… │
# │ (Multiply)          │                   │            │ block4c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_co… │ (None, 8, 8, 80)  │     38,400 │ block4c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_project_bn  │ (None, 8, 8, 80)  │        320 │ block4c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_drop        │ (None, 8, 8, 80)  │          0 │ block4c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block4c_add (Add)   │ (None, 8, 8, 80)  │          0 │ block4c_drop[0][… │
# │                     │                   │            │ block4b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_conv │ (None, 8, 8, 480) │     38,400 │ block4c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_bn   │ (None, 8, 8, 480) │      1,920 │ block5a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_expand_act… │ (None, 8, 8, 480) │          0 │ block5a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_dwconv      │ (None, 8, 8, 480) │     12,000 │ block5a_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_bn          │ (None, 8, 8, 480) │      1,920 │ block5a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_activation  │ (None, 8, 8, 480) │          0 │ block5a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_squeeze  │ (None, 480)       │          0 │ block5a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reshape  │ (None, 1, 1, 480) │          0 │ block5a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_reduce   │ (None, 1, 1, 20)  │      9,620 │ block5a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_expand   │ (None, 1, 1, 480) │     10,080 │ block5a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_se_excite   │ (None, 8, 8, 480) │          0 │ block5a_activati… │
# │ (Multiply)          │                   │            │ block5a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_co… │ (None, 8, 8, 112) │     53,760 │ block5a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5a_project_bn  │ (None, 8, 8, 112) │        448 │ block5a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5a_project_… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block5b_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_expand_act… │ (None, 8, 8, 672) │          0 │ block5b_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_dwconv      │ (None, 8, 8, 672) │     16,800 │ block5b_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_bn          │ (None, 8, 8, 672) │      2,688 │ block5b_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_activation  │ (None, 8, 8, 672) │          0 │ block5b_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_squeeze  │ (None, 672)       │          0 │ block5b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reshape  │ (None, 1, 1, 672) │          0 │ block5b_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5b_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_se_excite   │ (None, 8, 8, 672) │          0 │ block5b_activati… │
# │ (Multiply)          │                   │            │ block5b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_co… │ (None, 8, 8, 112) │     75,264 │ block5b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_project_bn  │ (None, 8, 8, 112) │        448 │ block5b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_drop        │ (None, 8, 8, 112) │          0 │ block5b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5b_add (Add)   │ (None, 8, 8, 112) │          0 │ block5b_drop[0][… │
# │                     │                   │            │ block5a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5b_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block5c_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_expand_act… │ (None, 8, 8, 672) │          0 │ block5c_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_dwconv      │ (None, 8, 8, 672) │     16,800 │ block5c_expand_a… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_bn          │ (None, 8, 8, 672) │      2,688 │ block5c_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_activation  │ (None, 8, 8, 672) │          0 │ block5c_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_squeeze  │ (None, 672)       │          0 │ block5c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reshape  │ (None, 1, 1, 672) │          0 │ block5c_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block5c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_expand   │ (None, 1, 1, 672) │     19,488 │ block5c_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_se_excite   │ (None, 8, 8, 672) │          0 │ block5c_activati… │
# │ (Multiply)          │                   │            │ block5c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_co… │ (None, 8, 8, 112) │     75,264 │ block5c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_project_bn  │ (None, 8, 8, 112) │        448 │ block5c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_drop        │ (None, 8, 8, 112) │          0 │ block5c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block5c_add (Add)   │ (None, 8, 8, 112) │          0 │ block5c_drop[0][… │
# │                     │                   │            │ block5b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_conv │ (None, 8, 8, 672) │     75,264 │ block5c_add[0][0] │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_bn   │ (None, 8, 8, 672) │      2,688 │ block6a_expand_c… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_expand_act… │ (None, 8, 8, 672) │          0 │ block6a_expand_b… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv_pad  │ (None, 11, 11,    │          0 │ block6a_expand_a… │
# │ (ZeroPadding2D)     │ 672)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_dwconv      │ (None, 4, 4, 672) │     16,800 │ block6a_dwconv_p… │
# │ (DepthwiseConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_bn          │ (None, 4, 4, 672) │      2,688 │ block6a_dwconv[0… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_activation  │ (None, 4, 4, 672) │          0 │ block6a_bn[0][0]  │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_squeeze  │ (None, 672)       │          0 │ block6a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reshape  │ (None, 1, 1, 672) │          0 │ block6a_se_squee… │
# │ (Reshape)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_reduce   │ (None, 1, 1, 28)  │     18,844 │ block6a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_expand   │ (None, 1, 1, 672) │     19,488 │ block6a_se_reduc… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_se_excite   │ (None, 4, 4, 672) │          0 │ block6a_activati… │
# │ (Multiply)          │                   │            │ block6a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_co… │ (None, 4, 4, 192) │    129,024 │ block6a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6a_project_bn  │ (None, 4, 4, 192) │        768 │ block6a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_conv │ (None, 4, 4,      │    221,184 │ block6a_project_… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_bn   │ (None, 4, 4,      │      4,608 │ block6b_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_expand_act… │ (None, 4, 4,      │          0 │ block6b_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_dwconv      │ (None, 4, 4,      │     28,800 │ block6b_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_bn          │ (None, 4, 4,      │      4,608 │ block6b_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_activation  │ (None, 4, 4,      │          0 │ block6b_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_squeeze  │ (None, 1152)      │          0 │ block6b_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reshape  │ (None, 1, 1,      │          0 │ block6b_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6b_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_expand   │ (None, 1, 1,      │     56,448 │ block6b_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_se_excite   │ (None, 4, 4,      │          0 │ block6b_activati… │
# │ (Multiply)          │ 1152)             │            │ block6b_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_co… │ (None, 4, 4, 192) │    221,184 │ block6b_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_project_bn  │ (None, 4, 4, 192) │        768 │ block6b_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_drop        │ (None, 4, 4, 192) │          0 │ block6b_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6b_add (Add)   │ (None, 4, 4, 192) │          0 │ block6b_drop[0][… │
# │                     │                   │            │ block6a_project_… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_conv │ (None, 4, 4,      │    221,184 │ block6b_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_bn   │ (None, 4, 4,      │      4,608 │ block6c_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_expand_act… │ (None, 4, 4,      │          0 │ block6c_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_dwconv      │ (None, 4, 4,      │     28,800 │ block6c_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_bn          │ (None, 4, 4,      │      4,608 │ block6c_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_activation  │ (None, 4, 4,      │          0 │ block6c_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_squeeze  │ (None, 1152)      │          0 │ block6c_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reshape  │ (None, 1, 1,      │          0 │ block6c_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6c_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_expand   │ (None, 1, 1,      │     56,448 │ block6c_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_se_excite   │ (None, 4, 4,      │          0 │ block6c_activati… │
# │ (Multiply)          │ 1152)             │            │ block6c_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_co… │ (None, 4, 4, 192) │    221,184 │ block6c_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_project_bn  │ (None, 4, 4, 192) │        768 │ block6c_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_drop        │ (None, 4, 4, 192) │          0 │ block6c_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6c_add (Add)   │ (None, 4, 4, 192) │          0 │ block6c_drop[0][… │
# │                     │                   │            │ block6b_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_conv │ (None, 4, 4,      │    221,184 │ block6c_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_bn   │ (None, 4, 4,      │      4,608 │ block6d_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_expand_act… │ (None, 4, 4,      │          0 │ block6d_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_dwconv      │ (None, 4, 4,      │     28,800 │ block6d_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_bn          │ (None, 4, 4,      │      4,608 │ block6d_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_activation  │ (None, 4, 4,      │          0 │ block6d_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_squeeze  │ (None, 1152)      │          0 │ block6d_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reshape  │ (None, 1, 1,      │          0 │ block6d_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block6d_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_expand   │ (None, 1, 1,      │     56,448 │ block6d_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_se_excite   │ (None, 4, 4,      │          0 │ block6d_activati… │
# │ (Multiply)          │ 1152)             │            │ block6d_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_co… │ (None, 4, 4, 192) │    221,184 │ block6d_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_project_bn  │ (None, 4, 4, 192) │        768 │ block6d_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_drop        │ (None, 4, 4, 192) │          0 │ block6d_project_… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block6d_add (Add)   │ (None, 4, 4, 192) │          0 │ block6d_drop[0][… │
# │                     │                   │            │ block6c_add[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_conv │ (None, 4, 4,      │    221,184 │ block6d_add[0][0] │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_bn   │ (None, 4, 4,      │      4,608 │ block7a_expand_c… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_expand_act… │ (None, 4, 4,      │          0 │ block7a_expand_b… │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_dwconv      │ (None, 4, 4,      │     10,368 │ block7a_expand_a… │
# │ (DepthwiseConv2D)   │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_bn          │ (None, 4, 4,      │      4,608 │ block7a_dwconv[0… │
# │ (BatchNormalizatio… │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_activation  │ (None, 4, 4,      │          0 │ block7a_bn[0][0]  │
# │ (Activation)        │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_squeeze  │ (None, 1152)      │          0 │ block7a_activati… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reshape  │ (None, 1, 1,      │          0 │ block7a_se_squee… │
# │ (Reshape)           │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_reduce   │ (None, 1, 1, 48)  │     55,344 │ block7a_se_resha… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_expand   │ (None, 1, 1,      │     56,448 │ block7a_se_reduc… │
# │ (Conv2D)            │ 1152)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_se_excite   │ (None, 4, 4,      │          0 │ block7a_activati… │
# │ (Multiply)          │ 1152)             │            │ block7a_se_expan… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_co… │ (None, 4, 4, 320) │    368,640 │ block7a_se_excit… │
# │ (Conv2D)            │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ block7a_project_bn  │ (None, 4, 4, 320) │      1,280 │ block7a_project_… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_conv (Conv2D)   │ (None, 4, 4,      │    409,600 │ block7a_project_… │
# │                     │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_bn              │ (None, 4, 4,      │      5,120 │ top_conv[0][0]    │
# │ (BatchNormalizatio… │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ top_activation      │ (None, 4, 4,      │          0 │ top_bn[0][0]      │
# │ (Activation)        │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_5     │ (None, 8, 8,      │          0 │ top_activation[0… │
# │ (UpSampling2D)      │ 1280)             │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_4       │ (None, 8, 8,      │          0 │ up_sampling2d_5[… │
# │ (Concatenate)       │ 1952)             │            │ block6a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 256) │  4,497,664 │ concatenate_4[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 256) │      1,024 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_5 (Dropout) │ (None, 8, 8, 256) │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_6     │ (None, 16, 16,    │          0 │ dropout_5[0][0]   │
# │ (UpSampling2D)      │ 256)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_5       │ (None, 16, 16,    │          0 │ up_sampling2d_6[… │
# │ (Concatenate)       │ 496)              │            │ block4a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │    571,520 │ concatenate_5[0]… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_6 (Dropout) │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_7     │ (None, 32, 32,    │          0 │ dropout_6[0][0]   │
# │ (UpSampling2D)      │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_6       │ (None, 32, 32,    │          0 │ up_sampling2d_7[… │
# │ (Concatenate)       │ 272)              │            │ block3a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │    156,736 │ concatenate_6[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_7 (Dropout) │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_8     │ (None, 64, 64,    │          0 │ dropout_7[0][0]   │
# │ (UpSampling2D)      │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_7       │ (None, 64, 64,    │          0 │ up_sampling2d_8[… │
# │ (Concatenate)       │ 160)              │            │ block2a_expand_a… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │     46,112 │ concatenate_7[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_8 (Dropout) │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ up_sampling2d_9     │ (None, 128, 128,  │          0 │ dropout_8[0][0]   │
# │ (UpSampling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 128, 128,  │      4,624 │ up_sampling2d_9[… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_9 (Dropout) │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 128, 128,  │         68 │ dropout_9[0][0]   │
# │                     │ 4)                │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 27,898,809 (106.43 MB)
#  Trainable params: 9,285,264 (35.42 MB)
#  Non-trainable params: 43,015 (168.03 KB)
#  Optimizer params: 18,570,530 (70.84 MB)

# %%
# Visualize training and validation metrics
def plot_training_history(history):
    metrics = ["loss", "accuracy",'dice_coef']
    for metric in metrics:
        plt.plot(history.history[metric], label=f"Train {metric}")
        plt.plot(history.history[f"val_{metric}"], label=f"Validation {metric}")
        plt.title(f"{metric.capitalize()} Over Epochs")
        plt.xlabel("Epochs")
        plt.ylabel(metric.capitalize())
        plt.legend()
        plt.show()

plot_training_history(history)

# %%
import matplotlib.pyplot as plt

# Assuming 'history' contains the training history
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.legend()
plt.show()
plt.plot(history.history['val_accuracy'], label='Validation Accuracy',color='r')
plt.legend()
plt.show()
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.legend()

# %%
from tensorflow.keras.models import load_model



best_model_path = "/kaggle/working/best_model.keras"
best_model = load_model(best_model_path, safe_mode=False,
                         custom_objects={'weighted_dice_loss': weighted_dice_loss, 
                                         'dice_coef': dice_coef})

# %%
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
import os

def visualize_prediction(model, images_path, masks_path, num_samples=1):
    """
    Visualize model predictions for brain tumor segmentation
    
    Parameters:
    - model: Trained Keras model
    - images_path: Path to saved image numpy files
    - masks_path: Path to saved mask numpy files
    - num_samples: Number of samples to visualize
    """
    # Get list of image and mask files
    image_files = sorted(os.listdir(images_path))
    mask_files = sorted(os.listdir(masks_path))
    
    # Randomly select samples
    random_indices = np.random.choice(len(image_files), num_samples, replace=False)
    
    for idx in random_indices:
        # Load image and ground truth mask
        img = np.load(os.path.join(images_path, image_files[idx]))
        true_mask = np.load(os.path.join(masks_path, mask_files[idx]))
        
        # Prepare image for prediction (add batch dimension)
        img_for_pred = np.expand_dims(img, axis=0)
        
        # Make prediction
        pred_mask = model.predict(img_for_pred)[0]
        
        # Create visualization
        plt.figure(figsize=(15, 5))
        
        # Original Image (first modality)
        plt.subplot(1, 3, 1)
        plt.imshow(img[:, :, 0], cmap='gray')
        plt.title('Original Image')
        plt.axis('off')
        
        # Ground Truth Mask
        plt.subplot(1, 3, 2)
        true_mask_single = np.argmax(true_mask, axis=-1)
        plt.imshow(true_mask_single, cmap='gray')
        plt.title('Ground Truth Mask')
        plt.axis('off')
        
        # Predicted Mask
        plt.subplot(1, 3, 3)
        pred_mask_single = np.argmax(pred_mask, axis=-1)
        plt.imshow(pred_mask_single, cmap='gray')
        plt.title('Predicted Mask')
        plt.axis('off')
        
        plt.tight_layout()
        plt.show()

# Example usage:
# Load the best saved model
best_model_path = "/kaggle/working/best_model.keras"
best_model = tf.keras.models.load_model(
    best_model_path,safe_mode=False, 
    custom_objects={
        'weighted_dice_loss': lambda y_true, y_pred: weighted_dice_loss(y_true, y_pred, class_weights),
        'dice_coef': dice_coef
    }
)

# Paths to validation images and masks
val_images_path = "/kaggle/working/val_data/images"
val_masks_path = "/kaggle/working/val_data/masks"

# Visualize predictions
visualize_prediction(model, val_images_path, val_masks_path, num_samples=5)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# W0000 00:00:1734409697.221464      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "VALID" } } attr { key: "strides" value { list { i: 1 i: 1 i: 2 i: 2 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 3 } dim { size: 129 } dim { size: 129 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 3 } dim { size: 32 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 64 } dim { size: 64 } } }
# W0000 00:00:1734409697.222765      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "DepthwiseConv2dNative" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 64 } dim { size: 64 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 32 } dim { size: 1 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 64 } dim { size: 64 } } }
# W0000 00:00:1734409697.223170      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 32 } dim { size: 8 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 8 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.223356      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 8 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 8 } dim { size: 32 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.223577      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 64 } dim { size: 64 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 32 } dim { size: 16 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 16 } dim { size: 64 } dim { size: 64 } } }
# W0000 00:00:1734409697.223869      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 16 } dim { size: 64 } dim { size: 64 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 16 } dim { size: 96 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 96 } dim { size: 64 } dim { size: 64 } } }
# W0000 00:00:1734409697.224404      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 96 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 96 } dim { size: 4 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 4 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.224582      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 4 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 4 } dim { size: 96 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 96 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.225225      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 144 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 144 } dim { size: 6 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 6 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.225420      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 6 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 6 } dim { size: 144 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 144 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.226037      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 144 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 144 } dim { size: 6 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 6 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.226206      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 6 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 6 } dim { size: 144 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 144 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.226715      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 240 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 240 } dim { size: 10 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 10 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.226891      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 10 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 10 } dim { size: 240 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 240 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.227447      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 240 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 240 } dim { size: 10 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 10 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.227605      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 10 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 10 } dim { size: 240 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 240 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.229255      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 480 } dim { size: 20 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.229418      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 20 } dim { size: 480 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.230146      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 480 } dim { size: 20 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.230306      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 20 } dim { size: 480 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.232193      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 480 } dim { size: 20 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.232385      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 20 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 20 } dim { size: 480 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 480 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.233578      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 672 } dim { size: 28 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.233795      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 28 } dim { size: 672 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.234420      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 672 } dim { size: 28 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.234625      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 28 } dim { size: 672 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.235180      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 672 } dim { size: 28 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.235384      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 28 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 28 } dim { size: 672 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 672 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.235874      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 1152 } dim { size: 48 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.236074      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 48 } dim { size: 1152 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.236588      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 1152 } dim { size: 48 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.236799      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 48 } dim { size: 1152 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.237311      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 1152 } dim { size: 48 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.237521      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 48 } dim { size: 1152 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.238031      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 1152 } dim { size: 48 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.238237      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 48 } dim { size: 1 } dim { size: 1 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 48 } dim { size: 1152 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 1152 } dim { size: 1 } dim { size: 1 } } }
# W0000 00:00:1734409697.239803      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "SAME" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 32 } dim { size: 128 } dim { size: 128 } } } inputs { dtype: DT_FLOAT shape { dim { size: 3 } dim { size: 3 } dim { size: 32 } dim { size: 16 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 16 } dim { size: 128 } dim { size: 128 } } }
# W0000 00:00:1734409697.240012      23 op_level_cost_estimator.cc:699] Error in PredictCost() for the op: op: "Conv2D" attr { key: "T" value { type: DT_FLOAT } } attr { key: "data_format" value { s: "NCHW" } } attr { key: "dilations" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "explicit_paddings" value { list { } } } attr { key: "padding" value { s: "VALID" } } attr { key: "strides" value { list { i: 1 i: 1 i: 1 i: 1 } } } attr { key: "use_cudnn_on_gpu" value { b: true } } inputs { dtype: DT_FLOAT shape { dim { } dim { size: 16 } dim { size: 128 } dim { size: 128 } } } inputs { dtype: DT_FLOAT shape { dim { size: 1 } dim { size: 1 } dim { size: 16 } dim { size: 4 } } } device { type: "GPU" vendor: "NVIDIA" model: "Tesla T4" frequency: 1590 num_cores: 40 environment { key: "architecture" value: "7.5" } environment { key: "cuda" value: "12030" } environment { key: "cudnn" value: "8906" } num_registers: 65536 l1_cache_size: 24576 l2_cache_size: 4194304 shared_memory_size_per_multiprocessor: 65536 memory_size: 14619377664 bandwidth: 320064000 } outputs { dtype: DT_FLOAT shape { dim { } dim { size: 4 } dim { size: 128 } dim { size: 128 } } }
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 143ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step
